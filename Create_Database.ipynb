# %%
import dbstep.Dbstep as db
import numpy as np
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
import os 
from rdkit.Chem import rdMolTransforms



def calc_Boltzman_weights(mol, conformerId, minimizeIts=1000,T=293):
    """
    The `calc_Boltzman_weights` function calculates the energy of a molecule conformer using the MMFF (Merck Molecular Force Field) method. 
    It takes the molecule (`mol`), conformer ID (`conformerId`), and optional parameters for the number of minimization iterations (`minimizeIts`) and temperature (`T`).
    Return  Boltzman Weight of a molecule
    """
	ff = AllChem.MMFFGetMoleculeForceField(mol, AllChem.MMFFGetMoleculeProperties(mol), confId=conformerId)
	ff.Initialize()
	ff.CalcEnergy()
	
	if minimizeIts > 0:
		conv = ff.Minimize(maxIts=minimizeIts)
	energy= ff.CalcEnergy()
	
	results  = np.exp(-energy/(T*1.988*10**(-3)))
	return results


def smiles_to_xyz(smiles, output_folder,mode='basic'):
    """
    The `smiles_to_xyz` function takes a SMILES string, an output folder path, and a mode parameter as input.
    It creates .xyz files of a molecule based on the given SMILES string. It has three meyhods of conformer generation:
    1) "basic" - which uses ETDKG algorithm implemented in RDKit
    2) "conformer_sample" - which creates 10 conformers also using RDKit
    3) "conformer_energy" - which creates 10 conformers also using RDKit and also applies the calc_Boltzman_weights function to obtain Boltzman weights for conformers

    """
    mol = Chem.MolFromSmiles(smiles)
    if mode=='basic':
        mol = Chem.AddHs(mol)

        
        if mol is not None:
            # Add hydrogen atoms
            mol = Chem.AddHs(mol)
            
            # Generate 3D coordinates
            AllChem.EmbedMolecule(mol)
            conf = mol.GetConformer()
            rdMolTransforms.CanonicalizeConformer(conf)
            output_file_path = os.path.join(output_folder, f'{smiles.replace("/", "_")}.xyz')
            # Write coordinates and SMILES to .xyz file
            with open(output_file_path, 'w') as xyz_file:
                xyz_file.write(f"{mol.GetNumAtoms()}\n")
                xyz_file.write(f"{smiles}\n")

                for atom in mol.GetAtoms():
                    pos = conf.GetAtomPosition(atom.GetIdx())
                    symbol = atom.GetSymbol()
                    xyz_file.write(f"{symbol} {pos.x:.16f} {pos.y:.16f} {pos.z:.16f}\n")
            return output_file_path
    elif mode=='conformer_sample':
        conf_list=[]
        mol = Chem.AddHs(mol)
        AllChem.EmbedMultipleConfs(mol)
        conformers = mol.GetConformers()
        
        for i, conf in enumerate(conformers):
            if conf is not None:
                
                rdMolTransforms.CanonicalizeConformer(conf)
                output_file_path = os.path.join(output_folder, f'{smiles.replace("/", "_")}_{i}conf.xyz')
            
                # Write coordinates and SMILES to .xyz file
                with open(output_file_path, 'w') as xyz_file:
                    xyz_file.write(f"{mol.GetNumAtoms()}\n")
                    xyz_file.write(f"{smiles}_{i}conf\n")
                    for atom in mol.GetAtoms():
                        pos = conf.GetAtomPosition(atom.GetIdx())
                        symbol = atom.GetSymbol()
                        xyz_file.write(f"{symbol} {pos.x:.16f} {pos.y:.16f} {pos.z:.16f}\n")
                conf_list.append(output_file_path)
        return conf_list
    elif mode=='conformer_energy':
        conf_list=[]
        conf_weights =[]
        mol = Chem.AddHs(mol)
        AllChem.EmbedMultipleConfs(mol)
        conformers = mol.GetConformers()
        
        for i, conf in enumerate(conformers):
            if conf is not None:
                conf_weights.append(calc_Boltzman_weights(mol, i, minimizeIts=1000,T=293))
                rdMolTransforms.CanonicalizeConformer(conf)
                output_file_path = os.path.join(output_folder, f'{smiles.replace("/", "_")}_{i}conf.xyz')
            
                # Write coordinates and SMILES to .xyz file
                with open(output_file_path, 'w') as xyz_file:
                    xyz_file.write(f"{mol.GetNumAtoms()}\n")
                    xyz_file.write(f"{smiles}_{i}conf\n")
                    for atom in mol.GetAtoms():
                        pos = conf.GetAtomPosition(atom.GetIdx())
                        symbol = atom.GetSymbol()
                        xyz_file.write(f"{symbol} {pos.x:.16f} {pos.y:.16f} {pos.z:.16f}\n")
                conf_list.append(output_file_path)
                conf_weights = [float(i)/sum(conf_weights) for i in conf_weights]
        return conf_list, conf_weights


def write_smiles_to_file(smiles_list, output_file):
    with open(output_file, 'w') as smiles_file:
        for smiles in smiles_list:
            smiles_file.write(f"{smiles}\n")
# Out:
# /home/user/Desktop/MS/env/lib/python3.10/site-packages/dbstep/sterics.py:16: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def parallel_grid_scan(xy_grid, angle):

# %%
input_file = 'IDPI_DataSet_Final_JPR.xlsx'

df1 = pd.read_excel(input_file)

electrophileSMILES = df1['input electrophile SMILES'].values
nucleophileSMILES = df1['nucleophile SMILES'].values
catSMILES = df1['3,3 Catalyst Substituent '].values
output_folder = 'catxyz_files'
os.makedirs(output_folder, exist_ok=True)
unique_df = df1.drop_duplicates(subset='3,3 Catalyst Substituent ')

# %% [markdown]
# # Identify Candidate Atoms in Electrophiles

# %%
def find_c_o_atom_ids(smiles):
    """  
    Input SMILES string
    This function `find_c_o_atom_ids(smiles)` is designed to identify carbonyl group
    in a molecule represented by its SMILES notation. Here's a breakdown of what the function does:

    1) First look for aldehydes
    2) If none were found look for ketones
    connected to two oxygen atom

    Return IDs of identified atoms
    """
    found_oxygen = False
    mol = Chem.MolFromSmiles(smiles)
    co_ids = {'smiles': smiles, 'oxygen_atom_ids': [], 'carbon_atom_ids': []}
    if mol is not None:
        # Add hydrogen atoms
        #mol = Chem.AddHs(mol)

        # Find atom IDs for oxygen and carbon in the C=O group with a double bond
        for bond in mol.GetBonds():
            if bond.GetBondTypeAsDouble() == 2.0:
                atom1 = bond.GetBeginAtom()
                atom2 = bond.GetEndAtom()    

                if atom1.GetAtomicNum() == 6 and atom2.GetAtomicNum() == 8 and atom1.GetDegree() == 2:#no hydrogens so aldehydes have degree 2

                    found_oxygen = True
                    co_ids['carbon_atom_ids'].append(atom1.GetIdx())
                    co_ids['oxygen_atom_ids'].append(atom2.GetIdx())
                    #print(f"f {atom1.GetIdx()} {smiles}")
                    return co_ids
                elif atom2.GetAtomicNum() == 6 and atom1.GetAtomicNum() == 8 and atom2.GetDegree() == 2:

                    found_oxygen =True
                    co_ids['carbon_atom_ids'].append(atom2.GetIdx())
                    co_ids['oxygen_atom_ids'].append(atom1.GetIdx())
                    return co_ids
        if not found_oxygen:
            #mol = Chem.AddHs(mol
            
            for bond in mol.GetBonds():
                if bond.GetBondTypeAsDouble() == 2.0:
                    atom1 = bond.GetBeginAtom()
                    atom2 = bond.GetEndAtom()  
                    if atom1.GetAtomicNum() == 6 and atom2.GetAtomicNum() == 8:

                        found_oxygen = True
                        co_ids['carbon_atom_ids'].append(atom1.GetIdx())
                        co_ids['oxygen_atom_ids'].append(atom2.GetIdx())
                        return co_ids
                    elif atom2.GetAtomicNum() == 6 and atom1.GetAtomicNum() == 8:

                        found_oxygen =True
                        co_ids['carbon_atom_ids'].append(atom2.GetIdx())
                        co_ids['oxygen_atom_ids'].append(atom1.GetIdx())
                        return co_ids
            if not found_oxygen:
                print(smiles)
    else:
        return None




# Keep only unique SMILES entries
unique_df = df1.drop_duplicates(subset='input electrophile SMILES')
# Find atom IDs for oxygen and carbon in the C=O group with a double bond for each unique SMILES
results = []
for index, row in unique_df.iterrows():
    result = find_c_o_atom_ids(row['input electrophile SMILES'])
    if result:
        results.append(result)
   

# Display results
for result in results:
    if len(result['oxygen_atom_ids'])==1:
        print(f"SMILES: {result['smiles']}, Oxygen Atom IDs: {result['oxygen_atom_ids']}, Carbon Atom IDs: {result['carbon_atom_ids']}")
# Out:
# SMILES: O=Cc2ccc1ccccc1c2, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: COc2ccc1cc(C=O)ccc1c2, Oxygen Atom IDs: [9], Carbon Atom IDs: [8]
# SMILES: O=Cc2ccc1cc(Br)ccc1c2, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: O=Cc1ccccc1, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: O=Cc1ccccc1F, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: Cc1ccccc1C=O, Oxygen Atom IDs: [8], Carbon Atom IDs: [7]
# SMILES: Cc1cccc(C=O)c1, Oxygen Atom IDs: [7], Carbon Atom IDs: [6]
# SMILES: Cc1ccc(C=O)cc1, Oxygen Atom IDs: [6], Carbon Atom IDs: [5]
# SMILES: CC(C)(C)c1ccc(C=O)cc1, Oxygen Atom IDs: [9], Carbon Atom IDs: [8]
# SMILES: O=C/C=C/c1ccccc1, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: CCCCCCCCCC=O, Oxygen Atom IDs: [10], Carbon Atom IDs: [9]
# SMILES: CCCCC=O, Oxygen Atom IDs: [5], Carbon Atom IDs: [4]
# SMILES: O=CCCc1ccccc1, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: CC(C)CC=O, Oxygen Atom IDs: [5], Carbon Atom IDs: [4]
# SMILES: C1CC=[O+]C1, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: C1CC[O+]=CC1, Oxygen Atom IDs: [3], Carbon Atom IDs: [4]
# SMILES: C1CCC=[O+]CC1, Oxygen Atom IDs: [4], Carbon Atom IDs: [3]
# SMILES: C1C=[O+]c2ccccc12, Oxygen Atom IDs: [2], Carbon Atom IDs: [1]
# SMILES: C1Cc2ccccc2[O+]=C1, Oxygen Atom IDs: [8], Carbon Atom IDs: [9]
# SMILES: C1Cc2ccccc2C=[O+]1, Oxygen Atom IDs: [9], Carbon Atom IDs: [8]
# SMILES: CC/C=C(C)/C(=O)/C=C/C(C)C, Oxygen Atom IDs: [6], Carbon Atom IDs: [5]
# SMILES: CC/C=C(C)/C(=O)/C=C/CCC, Oxygen Atom IDs: [6], Carbon Atom IDs: [5]
# SMILES: CC/C=C(C)/C(=O)/C=C/CC(C)C, Oxygen Atom IDs: [6], Carbon Atom IDs: [5]
# SMILES: CC/C=C(C)/C(=O)/C=C/C(CC)CC, Oxygen Atom IDs: [6], Carbon Atom IDs: [5]
# SMILES: CC/C=C(C)/C(=O)/C=C/C1CC1, Oxygen Atom IDs: [6], Carbon Atom IDs: [5]
# SMILES: CC/C=C(C)/C(=O)/C=C/C1CCC1, Oxygen Atom IDs: [6], Carbon Atom IDs: [5]
# SMILES: CC/C=C(C)/C(=O)/C=C/C1CCCC1, Oxygen Atom IDs: [6], Carbon Atom IDs: [5]
# SMILES: CC/C=C(C)/C(=O)/C=C/C1CCCCC1, Oxygen Atom IDs: [6], Carbon Atom IDs: [5]
# SMILES: CCCCC/C=C(C)/C(=O)/C=C/C(C)C, Oxygen Atom IDs: [9], Carbon Atom IDs: [8]
# SMILES: C/C(=C\CCCCCl)C(=O)/C=C/C(C)C, Oxygen Atom IDs: [9], Carbon Atom IDs: [8]
# SMILES: C/C(=C\CCc1ccccc1)C(=O)/C=C/C(C)C, Oxygen Atom IDs: [12], Carbon Atom IDs: [11]
# SMILES: C/C=C(C)/C(=O)/C=C/C(C)C, Oxygen Atom IDs: [5], Carbon Atom IDs: [4]
# SMILES: C/C=C(C)/C(=O)/C=C/C(C)(C)C, Oxygen Atom IDs: [5], Carbon Atom IDs: [4]
# SMILES: CC/C=C(C)/C(=O)/C=C/c1ccccc1Br, Oxygen Atom IDs: [6], Carbon Atom IDs: [5]
# SMILES: O=CCCC(=O)c1ccccc1, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: Cc1ccc(C(=O)CCC=O)cc1, Oxygen Atom IDs: [10], Carbon Atom IDs: [9]
# SMILES: O=CCCC(=O)c1ccc(Br)cc1, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: N#Cc1ccc(C(=O)CCC=O)cc1, Oxygen Atom IDs: [11], Carbon Atom IDs: [10]
# SMILES: CC(=O)CCC=O, Oxygen Atom IDs: [6], Carbon Atom IDs: [5]
# SMILES: O=CCCC(=O)C1CCCCC1, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: CCCCCCCCC#CC(=O)CCC=O, Oxygen Atom IDs: [15], Carbon Atom IDs: [14]
# SMILES: O=CCCCC(=O)c1ccccc1, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: CC(=O)CCCC=O, Oxygen Atom IDs: [7], Carbon Atom IDs: [6]
# SMILES: CC(=O)CCC(=O)c1ccccc1, Oxygen Atom IDs: [2], Carbon Atom IDs: [1]
# SMILES: CC(=O)CCC(=O)COCc1ccccc1, Oxygen Atom IDs: [2], Carbon Atom IDs: [1]
# SMILES: CC(=O)CCC(C)=O, Oxygen Atom IDs: [2], Carbon Atom IDs: [1]
# SMILES: COC(=O)/C=C/c1ccccc1, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: COC(=O)/C=C/c1ccc(C)cc1, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: COC(=O)/C=C/c1cccc(C)c1, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: COC(=O)/C=C/c1ccccc1C, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: COC(=O)/C=C/c1ccc(F)cc1, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: COC(=O)/C=C/c1ccc(Cl)cc1, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: COC(=O)/C=C/c1ccc(Br)cc1, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: COC(=O)/C=C/c1cccc2ccccc12, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: COC(=O)/C=C/c1ccc(OC)cc1, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: COC(=O)/C=C/c1ccc(C#N)cc1, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: COC(=O)/C=C/c1ccc(N(=O)=O)cc1, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: COC(=O)/C=C/c2ccc1OCOc1c2, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: COC(=O)/C=C/c1ccco1, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: COC(=O)/C=C/CCc1ccccc1, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: CCCCCCC/C=C/C(=O)OC, Oxygen Atom IDs: [10], Carbon Atom IDs: [9]
# SMILES: COC(=O)/C=C/C(C)C, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: CC(=O)c2ccc1ccccc1c2, Oxygen Atom IDs: [2], Carbon Atom IDs: [1]
# SMILES: CCC(=O)c2ccc1cc(OC)ccc1c2, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: CC(=O)c1cccc2ccccc12, Oxygen Atom IDs: [2], Carbon Atom IDs: [1]
# SMILES: CC(=O)c1ccccc1, Oxygen Atom IDs: [2], Carbon Atom IDs: [1]
# SMILES: CC(=O)c2ccc(c1ccccc1)cc2, Oxygen Atom IDs: [2], Carbon Atom IDs: [1]
# SMILES: CC(=O)c1ccc(C(C)(C)C)cc1, Oxygen Atom IDs: [2], Carbon Atom IDs: [1]
# SMILES: COc1ccc(C(C)=O)cc1, Oxygen Atom IDs: [8], Carbon Atom IDs: [6]
# SMILES: COc1ccc(C(C)=O)cc1OC, Oxygen Atom IDs: [8], Carbon Atom IDs: [6]
# SMILES: CC(=O)c1cc(C)cc(C)c1, Oxygen Atom IDs: [2], Carbon Atom IDs: [1]
# SMILES: CC(=O)c1cccs1, Oxygen Atom IDs: [2], Carbon Atom IDs: [1]
# SMILES: O=C1CCc2ccccc12, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: CC(=O)C1CCCCC1, Oxygen Atom IDs: [2], Carbon Atom IDs: [1]
# SMILES: CC(=O)CCc1ccccc1, Oxygen Atom IDs: [2], Carbon Atom IDs: [1]
# SMILES: CCCCCC(C)=O, Oxygen Atom IDs: [7], Carbon Atom IDs: [5]
# SMILES: CC(=O)C#Cc1ccccc1, Oxygen Atom IDs: [2], Carbon Atom IDs: [1]
# SMILES: CC(=O)/C=C/c1ccc(Cl)cc1, Oxygen Atom IDs: [2], Carbon Atom IDs: [1]
# SMILES: CC(=O)/C=C/c1ccc(C)cc1, Oxygen Atom IDs: [2], Carbon Atom IDs: [1]
# SMILES: CC(=O)/C=C/c2ccc1OCOc1c2, Oxygen Atom IDs: [2], Carbon Atom IDs: [1]
# SMILES: CC(=O)/C=C/c1ccco1, Oxygen Atom IDs: [2], Carbon Atom IDs: [1]
# SMILES: CC(=O)/C=C/c1ccccc1, Oxygen Atom IDs: [2], Carbon Atom IDs: [1]
# SMILES: CC(=O)/C(C)=C/c1ccccc1, Oxygen Atom IDs: [2], Carbon Atom IDs: [1]
# SMILES: CC(C)(C)C=O, Oxygen Atom IDs: [5], Carbon Atom IDs: [4]
# SMILES: O=CCOCc1ccccc1, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: COC(=O)CCC=O, Oxygen Atom IDs: [7], Carbon Atom IDs: [6]
# SMILES: CC(C)C=O, Oxygen Atom IDs: [4], Carbon Atom IDs: [3]
# SMILES: COc1cccc(C=O)c1, Oxygen Atom IDs: [8], Carbon Atom IDs: [7]
# SMILES: N#Cc1cccc(C=O)c1, Oxygen Atom IDs: [8], Carbon Atom IDs: [7]
# SMILES: O=Cc1cccs1, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: O=CC1CCCCC1, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: O=Cc1cccc(F)c1, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: O=Cc1ccc(F)cc1, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: O=Cc1ccc(Br)cc1, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: O=CCCCCCCBr, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: O=CCCCCCCCOCc1ccccc1, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: C=CCCCCCCCCC=O, Oxygen Atom IDs: [11], Carbon Atom IDs: [10]
# SMILES: CC=O, Oxygen Atom IDs: [2], Carbon Atom IDs: [1]
# SMILES: CCC1(C)C=CC(=O)C=C1, Oxygen Atom IDs: [7], Carbon Atom IDs: [6]
# SMILES: CCCC1(C)C=CC(=O)C=C1, Oxygen Atom IDs: [8], Carbon Atom IDs: [7]
# SMILES: CC1(C)C=CC(=O)C=C1, Oxygen Atom IDs: [6], Carbon Atom IDs: [5]
# SMILES: CC(C)C1(C)C=CC(=O)C=C1, Oxygen Atom IDs: [8], Carbon Atom IDs: [7]
# SMILES: C=CCC1(C)C=CC(=O)C=C1, Oxygen Atom IDs: [8], Carbon Atom IDs: [7]
# SMILES: C/C(C)=C\CCC1(C)C=CC(=O)C=C1, Oxygen Atom IDs: [11], Carbon Atom IDs: [10]
# SMILES: CC2(Cc1ccccc1)C=CC(=O)C=C2, Oxygen Atom IDs: [12], Carbon Atom IDs: [11]
# SMILES: CC2(CCc1ccccc1)C=CC(=O)C=C2, Oxygen Atom IDs: [13], Carbon Atom IDs: [12]
# SMILES: CC2(c1ccccc1)C=CC(=O)C=C2, Oxygen Atom IDs: [11], Carbon Atom IDs: [10]
# SMILES: COC1(C)C=CC(=O)C=C1, Oxygen Atom IDs: [7], Carbon Atom IDs: [6]
# SMILES: CC1(C#N)C=CC(=O)C=C1, Oxygen Atom IDs: [7], Carbon Atom IDs: [6]
# SMILES: COC(=O)C1(C)C=CC(=O)C=C1, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: C/C=C/1CCCCC1=O, Oxygen Atom IDs: [8], Carbon Atom IDs: [7]
# SMILES: CC/C=C/1CCCCC1=O, Oxygen Atom IDs: [9], Carbon Atom IDs: [8]
# SMILES: C=C1CCCC1=O, Oxygen Atom IDs: [6], Carbon Atom IDs: [5]
# SMILES: C/C=C/1CCCC1=O, Oxygen Atom IDs: [7], Carbon Atom IDs: [6]
# SMILES: CC/C=C/1CCCC1=O, Oxygen Atom IDs: [8], Carbon Atom IDs: [7]
# SMILES: CCCC/C=C/1CCCC1=O, Oxygen Atom IDs: [10], Carbon Atom IDs: [9]
# SMILES: C/C(C)=C\1CCCC1=O, Oxygen Atom IDs: [8], Carbon Atom IDs: [7]
# SMILES: C/C=C/1CCCC(C)(C)C1=O, Oxygen Atom IDs: [10], Carbon Atom IDs: [9]
# SMILES: C=C1CCCC(C)(C)C1=O, Oxygen Atom IDs: [9], Carbon Atom IDs: [8]
# SMILES: C=C1C(=O)CCCC1(C)C, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: C=C1CCC(C)=CC1=O, Oxygen Atom IDs: [8], Carbon Atom IDs: [7]
# SMILES: C=C1CCC=C(C)C1=O, Oxygen Atom IDs: [8], Carbon Atom IDs: [7]
# SMILES: C=C1CC(C)(C)C=CC1=O, Oxygen Atom IDs: [9], Carbon Atom IDs: [8]
# SMILES: C=C2CCc1ccccc1C2=O, Oxygen Atom IDs: [11], Carbon Atom IDs: [10]
# SMILES: COC(=O)/C=C/c1cccc(Br)c1, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: COC(=O)/C=C/c1ccccc1Br, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: COC(=O)/C=C/c1ccc(C(F)(F)F)cc1, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: COC(=O)/C=C/c1cccs1, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: COC(=O)/C=C/CC(C)C, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: CCC/C=C/C(=O)OC, Oxygen Atom IDs: [6], Carbon Atom IDs: [5]
# SMILES: CC/C=C/C(=O)OC, Oxygen Atom IDs: [5], Carbon Atom IDs: [4]
# SMILES: COC(=O)/C=C/CBr, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: C/C=C/C(=O)OC, Oxygen Atom IDs: [4], Carbon Atom IDs: [3]
# SMILES: C=C(C=O)CC, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: C=C(C=O)Cc1ccccc1, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: C/C=C/C=O, Oxygen Atom IDs: [4], Carbon Atom IDs: [3]
# SMILES: CC/C=C(C)/C=O, Oxygen Atom IDs: [6], Carbon Atom IDs: [5]
# SMILES: O=CC1=CCCCC1, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: C=C(C)C=O, Oxygen Atom IDs: [4], Carbon Atom IDs: [3]
# SMILES: C=CCCCCCCCC(=C)C=O, Oxygen Atom IDs: [12], Carbon Atom IDs: [11]
# SMILES: C=C(C=O)CCCCO[Si](C)(C)C(C)(C)C, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: C=C(C=O)Cc1ccccc1F, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]
# SMILES: CC/C=C/C=O, Oxygen Atom IDs: [5], Carbon Atom IDs: [4]
# SMILES: CCC/C=C/C=O, Oxygen Atom IDs: [6], Carbon Atom IDs: [5]
# SMILES: CCCCCCC/C=C/C=O, Oxygen Atom IDs: [10], Carbon Atom IDs: [9]
# SMILES: CC(C)C/C=C/C=O, Oxygen Atom IDs: [7], Carbon Atom IDs: [6]
# SMILES: CCOC(=O)/C=C/C=O, Oxygen Atom IDs: [8], Carbon Atom IDs: [7]
# SMILES: COc1ccc(/C=C/C=O)cc1, Oxygen Atom IDs: [9], Carbon Atom IDs: [8]
# SMILES: C=Cc1cccc(/C=C/C=O)c1, Oxygen Atom IDs: [10], Carbon Atom IDs: [9]
# SMILES: O=C/C=C/c1ccc(Br)cc1, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: O=C/C=C/c1ccc(Cl)cc1, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: O=C/C=C/c1ccco1, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: C/C=C(C)/C=O, Oxygen Atom IDs: [5], Carbon Atom IDs: [4]
# SMILES: O=CC1=CCCC1, Oxygen Atom IDs: [0], Carbon Atom IDs: [1]
# SMILES: C=CC=O, Oxygen Atom IDs: [3], Carbon Atom IDs: [2]

# %% [markdown]
# # Identify Candidate Atoms in Nucleophiles

# %%
def find_terminal_double_bonded_carbons(smiles):
    """  
    Input SMILES string
    This function `find_terminal_double_bonded_carbons(smiles)` is designed to identify terminal double-bonded carbons
    in a molecule represented by its SMILES notation. Here's a breakdown of what the function does:

    1) First look for the terminal double carbon bonds
    2) If none were found look for double bonds between carbon atoms where one atom is
    connected to two oxygen atom
    3) If none in two previous searches were found all carbons with double bonds were
    considered
    Return IDs of terminal carbons
    """
    terminal_double_bonded_carbons = {'smiles': smiles, 'terminal_atoms': [], 'non_terminal_atoms': [], 'returned_from': ''}    
    mol = Chem.MolFromSmiles(smiles)
    found_terminal = False
    if mol is not None:
        # Add hydrogen atoms
        #mol = Chem.AddHs(mol)
        for bond in mol.GetBonds():
            if bond.GetBondTypeAsDouble() == 2.0:  # Check if the bond is a double bond
                atom1 = bond.GetBeginAtom()
                atom2 = bond.GetEndAtom()
                # Check if both atoms are carbon and at least one of them is terminal
                if atom1.GetAtomicNum() == 6 and atom2.GetAtomicNum() == 6:
                    if atom1.GetDegree() == 1 and atom2.GetDegree() > 1:  # Check if atom1 is terminal and atom2 is non-terminal
                            terminal_double_bonded_carbons['terminal_atoms'].append(atom1.GetIdx())
                            terminal_double_bonded_carbons['non_terminal_atoms'].append(atom2.GetIdx())
                            found_terminal = True
                            terminal_double_bonded_carbons['returned_from'] = 'terminal'
                    elif atom1.GetDegree() > 1 and atom2.GetDegree() == 1:  # Check if atom2 is terminal and atom1 is non-terminal
                            terminal_double_bonded_carbons['terminal_atoms'].append(atom2.GetIdx())
                            terminal_double_bonded_carbons['non_terminal_atoms'].append(atom1.GetIdx())
                            terminal_double_bonded_carbons['returned_from'] = 'terminal'
                            found_terminal = True
                                  
        if not found_terminal:
            for bond in mol.GetBonds():
                if bond.GetBondTypeAsDouble() == 2.0:  # Check if the bond is a double bond
                    atom1 = bond.GetBeginAtom()
                    atom2 = bond.GetEndAtom()
                    # Check if both atoms are carbon and at least one of them is terminal
                    if atom1.GetAtomicNum() == 6 and atom2.GetAtomicNum() == 6:
                        if atom1.GetDegree() == 3 and len([neighbor for neighbor in atom1.GetNeighbors() if neighbor.GetAtomicNum() == 8]) == 2:
                                        terminal_double_bonded_carbons['terminal_atoms'].append(atom2.GetIdx())
                                        terminal_double_bonded_carbons['non_terminal_atoms'].append(atom1.GetIdx())
                                        found_terminal = True
                                        terminal_double_bonded_carbons['returned_from'] = 'oxygen'
                        elif atom2.GetDegree() == 3 and len([neighbor for neighbor in atom2.GetNeighbors() if neighbor.GetAtomicNum() == 8]) == 2:
                                        terminal_double_bonded_carbons['terminal_atoms'].append(atom1.GetIdx())
                                        terminal_double_bonded_carbons['non_terminal_atoms'].append(atom2.GetIdx())
                                        found_terminal = True
                                        terminal_double_bonded_carbons['returned_from'] = 'oxygen'

        if not found_terminal:
            for bond in mol.GetBonds():
                if bond.GetBondTypeAsDouble() == 2.0:  # Check if the bond is a double bond
                    atom1 = bond.GetBeginAtom()
                    atom2 = bond.GetEndAtom()
                    # Check if both atoms are carbon and at least one of them is terminal
                    if atom1.GetAtomicNum() == 6 and atom2.GetAtomicNum() == 6:
                        terminal_double_bonded_carbons['terminal_atoms'].append(atom1.GetIdx())
                        terminal_double_bonded_carbons['non_terminal_atoms'].append(atom2.GetIdx())
                        terminal_double_bonded_carbons['terminal_atoms'].append(atom2.GetIdx())
                        terminal_double_bonded_carbons['non_terminal_atoms'].append(atom1.GetIdx())
                        terminal_double_bonded_carbons['returned_from'] = 'carbon nonterminal'
    return terminal_double_bonded_carbons



unique_df = df1.drop_duplicates(subset='nucleophile SMILES')

results = []
for index, row in unique_df.iterrows():
    result = find_terminal_double_bonded_carbons(row['nucleophile SMILES'])
    if result:
        results.append(result)

# Display results
for result in results:
    #if not result['terminal_atoms']:
        print(f"SMILES: {result['smiles']}, terminal_atoms: {result['terminal_atoms']},non_terminal_atoms: {result['non_terminal_atoms']}")
# Out:
# SMILES: C=CC[Si](C)(C)C, terminal_atoms: [0],non_terminal_atoms: [1]
# SMILES: C=C(OC)O[Si](C)(C)C(C)(C)C, terminal_atoms: [0],non_terminal_atoms: [1]
# SMILES: C=C(OCc1ccccc1)O[Si](C)(C)C(C)(C)C, terminal_atoms: [0],non_terminal_atoms: [1]
# SMILES: C=C(OC1CCCCC1)O[Si](C)(C)C(C)(C)C, terminal_atoms: [0],non_terminal_atoms: [1]
# SMILES: C=C(O[Si](C)(C)C(C)(C)C)c1ccccc1, terminal_atoms: [0],non_terminal_atoms: [1]
# SMILES: C=C(/C=C/c1ccccc1)O[Si](C)(C)C(C)(C)C, terminal_atoms: [0],non_terminal_atoms: [1]
# SMILES: C=C/C=C(OC(C)C)\O[Si](C)(C)C(C)(C)C, terminal_atoms: [0],non_terminal_atoms: [1]
# SMILES: C=C1C=C(O[Si](C)(C)C)OC(C)(C)O1, terminal_atoms: [0],non_terminal_atoms: [1]
# SMILES: CC/C=C(C)/C(=O)/C=C/C(C)C, terminal_atoms: [2, 3, 7, 8],non_terminal_atoms: [3, 2, 8, 7]
# SMILES: CC/C=C(C)/C(=O)/C=C/CCC, terminal_atoms: [2, 3, 7, 8],non_terminal_atoms: [3, 2, 8, 7]
# SMILES: CC/C=C(C)/C(=O)/C=C/CC(C)C, terminal_atoms: [2, 3, 7, 8],non_terminal_atoms: [3, 2, 8, 7]
# SMILES: CC/C=C(C)/C(=O)/C=C/C(CC)CC, terminal_atoms: [2, 3, 7, 8],non_terminal_atoms: [3, 2, 8, 7]
# SMILES: CC/C=C(C)/C(=O)/C=C/C1CC1, terminal_atoms: [2, 3, 7, 8],non_terminal_atoms: [3, 2, 8, 7]
# SMILES: CC/C=C(C)/C(=O)/C=C/C1CCC1, terminal_atoms: [2, 3, 7, 8],non_terminal_atoms: [3, 2, 8, 7]
# SMILES: CC/C=C(C)/C(=O)/C=C/C1CCCC1, terminal_atoms: [2, 3, 7, 8],non_terminal_atoms: [3, 2, 8, 7]
# SMILES: CC/C=C(C)/C(=O)/C=C/C1CCCCC1, terminal_atoms: [2, 3, 7, 8],non_terminal_atoms: [3, 2, 8, 7]
# SMILES: CCCCC/C=C(C)/C(=O)/C=C/C(C)C, terminal_atoms: [5, 6, 10, 11],non_terminal_atoms: [6, 5, 11, 10]
# SMILES: C/C(=C\CCCCCl)C(=O)/C=C/C(C)C, terminal_atoms: [1, 2, 10, 11],non_terminal_atoms: [2, 1, 11, 10]
# SMILES: C/C(=C\CCc1ccccc1)C(=O)/C=C/C(C)C, terminal_atoms: [1, 2, 13, 14],non_terminal_atoms: [2, 1, 14, 13]
# SMILES: C/C=C(C)/C(=O)/C=C/C(C)C, terminal_atoms: [1, 2, 6, 7],non_terminal_atoms: [2, 1, 7, 6]
# SMILES: C/C=C(C)/C(=O)/C=C/C(C)(C)C, terminal_atoms: [1, 2, 6, 7],non_terminal_atoms: [2, 1, 7, 6]
# SMILES: CC/C=C(C)/C(=O)/C=C/c1ccccc1Br, terminal_atoms: [2, 3, 7, 8],non_terminal_atoms: [3, 2, 8, 7]
# SMILES: C=C(OC)O[Si](C)(C)C, terminal_atoms: [0],non_terminal_atoms: [1]
# SMILES: C=C(OCc1ccccc1)O[Si](C)(C)C, terminal_atoms: [0],non_terminal_atoms: [1]
# SMILES: CO/C(O[Si](C)(C)C)=C(C)/C, terminal_atoms: [8],non_terminal_atoms: [2]
# SMILES: CO/C(O[Si](C)(C)C)=C/1CCCCC1, terminal_atoms: [8],non_terminal_atoms: [2]
# SMILES: CO/C(O[Si](C)(C)C)=C/1CCCC1, terminal_atoms: [8],non_terminal_atoms: [2]
# SMILES: CO/C(O[Si](C)(C)C)=C/1CCC1, terminal_atoms: [8],non_terminal_atoms: [2]
# SMILES: CO/C(=C\c1ccccc1)O[Si](C)(C)C, terminal_atoms: [3],non_terminal_atoms: [2]
# SMILES: CO/C(=C/c1ccccc1)O[Si](C)(C)C, terminal_atoms: [3],non_terminal_atoms: [2]
# SMILES: CO/C(=C\C(C)C)O[Si](C)(C)C, terminal_atoms: [3],non_terminal_atoms: [2]
# SMILES: C=C(OC)O[Si](CC)(CC)CC, terminal_atoms: [0],non_terminal_atoms: [1]
# SMILES: C=C(OC)O[Si](C(C)C)(C(C)C)C(C)C, terminal_atoms: [0],non_terminal_atoms: [1]
# SMILES: C=CO[Si](CC)(CC)CC, terminal_atoms: [0],non_terminal_atoms: [1]
# SMILES: C=CO[Si](C)(C)C(C)(C)C, terminal_atoms: [0],non_terminal_atoms: [1]
# SMILES: C/C=C(C)/C=C/CCO, terminal_atoms: [1, 2, 4, 5],non_terminal_atoms: [2, 1, 5, 4]
# SMILES: C=C(C)C(=C)C, terminal_atoms: [0, 4],non_terminal_atoms: [1, 3]
# SMILES: C=CC(=C)C, terminal_atoms: [0, 3],non_terminal_atoms: [1, 2]
# SMILES: C=CC(=C)CC/C=C(C)\C, terminal_atoms: [0, 3],non_terminal_atoms: [1, 2]
# SMILES: C=C(C)/C=C(C)/C, terminal_atoms: [0],non_terminal_atoms: [1]
# SMILES: C=C/C=C/C, terminal_atoms: [0],non_terminal_atoms: [1]
# SMILES: C=C/C=C/CCCCCC, terminal_atoms: [0],non_terminal_atoms: [1]
# SMILES: C=C/C=C/C1CCCCC1, terminal_atoms: [0],non_terminal_atoms: [1]
# SMILES: C=C(C)/C=C/C, terminal_atoms: [0],non_terminal_atoms: [1]
# SMILES: C=C(C)C1=CCCCC1, terminal_atoms: [0],non_terminal_atoms: [1]
# SMILES: C=C(/C=C/C(C)(C)C)C(C)(C)C, terminal_atoms: [0],non_terminal_atoms: [1]
# SMILES: C=C(C)/C=C/CCOCc1ccccc1, terminal_atoms: [0],non_terminal_atoms: [1]
# SMILES: C1=CCC=C1, terminal_atoms: [0, 1, 3, 4],non_terminal_atoms: [1, 0, 4, 3]
# SMILES: C1=CCCC=C1, terminal_atoms: [0, 1, 4, 5],non_terminal_atoms: [1, 0, 5, 4]

# %%
from rdkit.Chem.rdmolfiles import  MolFromXYZFile
import itertools
import math

def calculate_distance(point1, point2):
    return math.sqrt((point1[0] - point2[0])**2 + (point1[1] - point2[1])**2 + (point1[2] - point2[2])**2)

def calculate_max_distance(coordinates):
    max_distance = 0.0
    
    # Use itertools to generate all combinations of points
    for pair in itertools.combinations(coordinates, 2):
        distance = calculate_distance(pair[0], pair[1])
        max_distance = max(max_distance, distance)
    
    return max_distance


def calculate_bounding_box_dimensions(coordinates):
    """    
    Input - list of cartesian coordinates
    This function  calculates the dimensions of a bounding box that encloses a set of 3D coordinates, based on cartesian coordinates, without accounting for different configurations
    Return Dimensions of bounding box (List)

    """    
    min_x, min_y, min_z = float('inf'), float('inf'), float('inf')
    max_x, max_y, max_z = float('-inf'), float('-inf'), float('-inf')

    for point in coordinates:
        x, y, z = point
        min_x = min(min_x, x)
        min_y = min(min_y, y)
        min_z = min(min_z, z)
        max_x = max(max_x, x)
        max_y = max(max_y, y)
        max_z = max(max_z, z)

    dimensions = [max_x - min_x, max_y - min_y, max_z - min_z]
    dimensions.sort(reverse=True)

    return dimensions

def get_coord(coord_filepath,id):

    """
    Input xyz file atom ID
    This `get_coord` function is designed to extract information from a molecular structure file in XYZ format.
    It than calculates max_distance, bounding_box_dimensions, displacement
    Return  max_distance (Float), bounding_box_dimensions (list),displace (Float)
    """

    mol = MolFromXYZFile(coord_filepath)
    positions = []
    mol = MolFromXYZFile(coord_filepath)
    if mol is not None:
        for i, atom in enumerate(mol.GetAtoms()):
                positions.append(mol.GetConformer().GetAtomPosition(i))
        max_distance = calculate_max_distance(positions)
        bounding_box_dimensions = calculate_bounding_box_dimensions(positions)
        displace = calculate_distance(mol.GetConformer().GetAtomPosition(id), [x / 2 for x in bounding_box_dimensions])
        return max_distance, bounding_box_dimensions,displace
    else:
        return None,None,None

# %% [markdown]
# # Calculate  %Vbur for 3,3' substiuent group

# %%
import os
import subprocess

directory_path = "low_energy"  # Replace with the actual path to your directory
output_file = "results.txt"


filename_list_file = "Atom_IDs.txt"  # Replace with the actual path to your filename list file

directory_path = "low_energy"  # Replace with the actual path to your directory
output_file = "results35.txt"
# Read the filenames from the specified file
with open(filename_list_file, "r") as filename_list:
    target_filenames = [line.split()[1] for line in filename_list.readlines() if line.strip()]
with open(filename_list_file, "r") as filename_list:
    AIDs= [line.split()[3] for line in filename_list.readlines() if line.strip()]

# Open the output file in write mode
with open(output_file, "w") as file:

    # Iterate over the target filenames
    for i in range(len(target_filenames)):
        target_filename = target_filenames[i]
        AID = AIDs[i]
        file_path = os.path.join(directory_path, target_filename)
        
        # Run db.dbstep command for each target file
        
        # Use subprocess to run the command
        result = db.dbstep(file_path,AID, commandline=True,volume=True,measure='classic',r=7.5)
            #result = subprocess.run(command, shell=True, capture_output=True, text=True)
        result = result.bur_vol
            # Write results to the output file
        file.write(f"Results for file {target_filename}:    {result}\n")

# %% [markdown]
# # Add Catalyst Parameters to the Dataset

# %%
input_file = 'IDPI_DataSet_Final_JPR.xlsx'
df1 = pd.read_excel(input_file)
print(len(df1[:]))
def delete_rows_with_same_values(df, columns_to_check):
    X = df.copy()  # Make a copy of the DataFrame to avoid modifying the original
    X.sort_values(by="ddG", ascending=False)
    # Identify rows where specified columns have the same value
    rows_to_delete = X.duplicated(subset=columns_to_check, keep='first') 

    # Invert the boolean mask to keep rows that don't have the same values in specified columns
    X_filtered = X[~rows_to_delete]

    return X_filtered

input_file2 = 'sterimol/results_sterimol.csv'
df2 = pd.read_csv(input_file2)


result = pd.merge(df1 ,df2, left_on='3,3 Catalyst Substituent ', right_on='old_name', how='left')

result.to_csv("sterimol/merged.csv")
# Out:
# 338
# 338

# %%
def run_dbstep(file_path, atom1, atom2):
    """
    Input .xyz file, identified atom IDs
    Function calculates all parameters used in this study: sterimol, %Vbur, bounding obx dimension max_distance, displacment and bounding box dimensions
    Return Steric Paramiters
    """
    mol = db.dbstep(file_path,atom1=atom1+1,atom2=atom2+1,commandline=True,sterimol=True,measure='classic')  #dbstep starts from 0 rdkit from 0
    mol2 = db.dbstep(file_path,atom2=atom2+1,commandline=True,volume=True,measure='classic')
    #Grab Sterimol Parameters
    L = mol.L
    Bmin = mol.Bmin
    Bmax = mol.Bmax
    bur_shell = mol2.bur_shell
    bur_vol = mol2.bur_vol
    
    max_distance, bounding_box_dimensions,disp = get_coord(file_path,atom2)
    if max_distance is not None:
        tot_V = bounding_box_dimensions[0]*bounding_box_dimensions[1]*bounding_box_dimensions[2]
        max_axis = np.max(bounding_box_dimensions)
        A2 = np.sort(bounding_box_dimensions)[-2]/max_axis
        min_axis = np.min(bounding_box_dimensions)/max_axis
        return L, Bmin,Bmax,bur_shell,bur_vol, max_distance, tot_V, disp,max_axis,A2,min_axis


def calculate_average(properties,mode='default',weights=[]):
    """"
    Input: Properties of interest (in our case those calculated in  run_dbstep), mode=(boltzman_max,boltzman_weighted,default) weights for boltzman_max,boltzman_weighted
    
    Function returns properties over confromers in 3 different modes boltzman_max - properites for conformer with min energy
    boltzman_weighted - as a weighted boltzman average of over conformers
    default - regular average over conformers 
    """
    num_conformers = len(properties)
    num_atoms = len(properties[0])  # Assuming all conformers have the same number of atoms
    num_properties = len(properties[0][0])  # Assuming all atoms have the same number of properties
    averages = [[0] * num_properties for _ in range(num_atoms)]  # Initialize averages for each property of each atom
    if mode=='default':
        for prop in properties:
            for atom_idx, atom_props in enumerate(prop):
                for prop_idx, val in enumerate(atom_props):
                    averages[atom_idx][prop_idx] += val / num_conformers
    elif mode=="boltzman_weighted":
        for prop, weight in zip(properties, weights):
            for atom_idx, atom_props in enumerate(prop):
                for prop_idx, val in enumerate(atom_props):
                    averages[atom_idx][prop_idx] += val * weight
        for atom_avg in averages:
            for prop_idx in range(num_properties):
                atom_avg[prop_idx] /= sum(weights)  # Normalize by the sum of weights
    elif mode=="boltzman_max":
        for prop, weight in zip(properties, weights):
            if weight==max(weights):
                for atom_idx, atom_props in enumerate(prop):
                    for prop_idx, val in enumerate(atom_props):
                        averages[atom_idx][prop_idx] = val 
    
                
    return averages

# %% [markdown]
# # Parameter Aquisition Pipeline

# %% [markdown]
# # Lowest energy conformer method

# %%
unique_df = df1.drop_duplicates(subset='input electrophile SMILES')

# Find Sterimol parameters for each unique SMILES
results = []
for index, row in unique_df.iterrows():
    properties = []
    c_o_info = find_c_o_atom_ids(row['input electrophile SMILES'])
    if c_o_info:
        smiles = c_o_info['smiles']
        oxygen_atom_id = c_o_info['oxygen_atom_ids']
        carbon_atom_id = c_o_info['carbon_atom_ids']

        # Create .xyz file
        output_folder = 'exyz_files_conf_sample'
        os.makedirs(output_folder, exist_ok=True)
        conformers, weights = smiles_to_xyz(smiles, output_folder,'conformer_energy')
        for conf in conformers:
            
            conformer_properties = []
            for i in range(len(oxygen_atom_id)):
                print(oxygen_atom_id[i])
                #L, Bmin,Bmax,bur_shell,bur_vol, max_distance, tot_V, disp,max_axis,A2,min_axis
                props  = run_dbstep(conf, oxygen_atom_id[i], carbon_atom_id[i])
                if props is not None:
                    conformer_properties.append(props)
            if props is not None:
                properties.append(conformer_properties)
            

        
        average_properties_array = calculate_average(properties,mode="boltzman_max",weights=weights)[0]
        #average_properties_array = np.array(average_properties)

       
        results.append({'smiles': smiles, 'L': average_properties_array[0], 'Bmin': average_properties_array[1], 
        'Bmax': average_properties_array[2], 'bur_shell': average_properties_array[3], 'bur_vol': average_properties_array[4], 
        'max_distance': average_properties_array[5], 'tot_V': average_properties_array[6], 'disp': average_properties_array[7],
         'max_axis': average_properties_array[8], 'A2': average_properties_array[9], 'min_axis': average_properties_array[10]})


# Display Sterimol results
results_df = pd.DataFrame(results)

# Save the results to a CSV file
results_csv_file = 'boltz_max_sterimol_results.csv'
results_df.to_csv(results_csv_file, index=False)
# Out:
# 0
#    exyz_files_conf_sample/O=Cc2ccc1ccccc1c2_0conf.xyz / Bmin:  1.70 / Bmax:  8.16 / L:  6.44
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.32       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1ccccc1c2_1conf.xyz / Bmin:  1.70 / Bmax:  6.85 / L:  8.50
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.32       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1ccccc1c2_2conf.xyz / Bmin:  1.70 / Bmax:  6.85 / L:  8.50
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.32       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1ccccc1c2_3conf.xyz / Bmin:  1.70 / Bmax:  8.16 / L:  6.44
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.32       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1ccccc1c2_4conf.xyz / Bmin:  1.70 / Bmax:  8.16 / L:  6.44
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.32       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1ccccc1c2_5conf.xyz / Bmin:  1.70 / Bmax:  6.85 / L:  8.50
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.32       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1ccccc1c2_6conf.xyz / Bmin:  1.70 / Bmax:  8.16 / L:  6.44
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.32       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1ccccc1c2_7conf.xyz / Bmin:  1.70 / Bmax:  8.16 / L:  6.44
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.32       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1ccccc1c2_8conf.xyz / Bmin:  1.70 / Bmax:  6.85 / L:  8.50
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.32       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1ccccc1c2_9conf.xyz / Bmin:  1.70 / Bmax:  6.85 / L:  8.50
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.32       0.00
# 9
#    exyz_files_conf_sample/COc2ccc1cc(C=O)ccc1c2_0conf.xyz / Bmin:  1.70 / Bmax:  8.93 / L:  8.49
#       R/Å     %V_Bur     %S_Bur
#      3.50      28.62       0.00
# 9
#    exyz_files_conf_sample/COc2ccc1cc(C=O)ccc1c2_1conf.xyz / Bmin:  1.70 / Bmax:  8.93 / L:  8.49
#       R/Å     %V_Bur     %S_Bur
#      3.50      28.62       0.00
# 9
#    exyz_files_conf_sample/COc2ccc1cc(C=O)ccc1c2_2conf.xyz / Bmin:  1.70 / Bmax:  8.10 / L:  9.43
#       R/Å     %V_Bur     %S_Bur
#      3.50      28.62       0.00
# 9
#    exyz_files_conf_sample/COc2ccc1cc(C=O)ccc1c2_3conf.xyz / Bmin:  1.70 / Bmax: 10.25 / L:  6.43
#       R/Å     %V_Bur     %S_Bur
#      3.50      28.63       0.00
# 9
#    exyz_files_conf_sample/COc2ccc1cc(C=O)ccc1c2_4conf.xyz / Bmin:  1.70 / Bmax:  9.41 / L:  7.37
#       R/Å     %V_Bur     %S_Bur
#      3.50      28.61       0.00
# 9
#    exyz_files_conf_sample/COc2ccc1cc(C=O)ccc1c2_5conf.xyz / Bmin:  1.70 / Bmax:  9.41 / L:  7.37
#       R/Å     %V_Bur     %S_Bur
#      3.50      28.62       0.00
# 9
#    exyz_files_conf_sample/COc2ccc1cc(C=O)ccc1c2_6conf.xyz / Bmin:  1.70 / Bmax: 10.25 / L:  6.43
#       R/Å     %V_Bur     %S_Bur
#      3.50      28.63       0.00
# 9
#    exyz_files_conf_sample/COc2ccc1cc(C=O)ccc1c2_7conf.xyz / Bmin:  1.70 / Bmax:  8.93 / L:  8.49
#       R/Å     %V_Bur     %S_Bur
#      3.50      28.62       0.00
# 9
#    exyz_files_conf_sample/COc2ccc1cc(C=O)ccc1c2_8conf.xyz / Bmin:  1.70 / Bmax:  9.41 / L:  7.37
#       R/Å     %V_Bur     %S_Bur
#      3.50      28.62       0.00
# 9
#    exyz_files_conf_sample/COc2ccc1cc(C=O)ccc1c2
f.xyz / Bmin:  1.70 / Bmax:  4.43 / L:  4.21
#       R/Å     %V_Bur     %S_Bur
#      3.50      27.17       0.00
# 3
#    exyz_files_conf_sample/C=CC=O_2conf.xyz / Bmin:  1.70 / Bmax:  4.43 / L:  4.21
#       R/Å     %V_Bur     %S_Bur
#      3.50      27.17       0.00
# 3
#    exyz_files_conf_sample/C=CC=O_3conf.xyz / Bmin:  1.70 / Bmax:  3.27 / L:  5.03
#       R/Å     %V_Bur     %S_Bur
#      3.50      25.84       0.00
# 3
#    exyz_files_conf_sample/C=CC=O_4conf.xyz / Bmin:  1.70 / Bmax:  4.43 / L:  4.21
#       R/Å     %V_Bur     %S_Bur
#      3.50      27.17       0.00
# 3
#    exyz_files_conf_sample/C=CC=O_5conf.xyz / Bmin:  1.70 / Bmax:  4.43 / L:  4.21
#       R/Å     %V_Bur     %S_Bur
#      3.50      27.17       0.00
# 3
#    exyz_files_conf_sample/C=CC=O_6conf.xyz / Bmin:  1.70 / Bmax:  3.27 / L:  5.03
#       R/Å     %V_Bur     %S_Bur
#      3.50      25.84       0.00
# 3
#    exyz_files_conf_sample/C=CC=O_7conf.xyz / Bmin:  1.70 / Bmax:  4.43 / L:  4.21
#       R/Å     %V_Bur     %S_Bur
#      3.50      27.17       0.00
# 3
#    exyz_files_conf_sample/C=CC=O_8conf.xyz / Bmin:  1.70 / Bmax:  4.43 / L:  4.21
#       R/Å     %V_Bur     %S_Bur
#      3.50      27.17       0.00
# 3
#    exyz_files_conf_sample/C=CC=O_9conf.xyz / Bmin:  1.70 / Bmax:  3.27 / L:  5.03
#       R/Å     %V_Bur     %S_Bur
#      3.50      25.84       0.00

# %%
unique_df = df1.drop_duplicates(subset='nucleophile SMILES')

# Find Sterimol parameters for each unique SMILES
results = []
for index, row in unique_df.iterrows():
    properties = []
    terminal_double_bonded_carbons = find_terminal_double_bonded_carbons(row['nucleophile SMILES'])
    if terminal_double_bonded_carbons:
        smiles = terminal_double_bonded_carbons['smiles']
        terminal_atom_ids = terminal_double_bonded_carbons['terminal_atoms']
        non_terminal_atoms = terminal_double_bonded_carbons['non_terminal_atoms']
        # Create .xyz file
        output_folder = 'nxyz_files_conf_sample'
        os.makedirs(output_folder, exist_ok=True)
        #output_file_path = os.path.join(output_folder, f'{smiles.replace("/", "_")}.xyz')
        conformers, weights = smiles_to_xyz(smiles, output_folder,'conformer_energy')
        for conf in conformers:
            
            conformer_properties = []
            for i in range(len(terminal_atom_ids)):
                print(terminal_atom_ids[i])
                #L, Bmin,Bmax,bur_shell,bur_vol, max_distance, tot_V, disp,max_axis,A2,min_axis
                props  = run_dbstep(conf, terminal_atom_ids[i], non_terminal_atoms[i])
                if props is not None:
                    conformer_properties.append(props)
            if props is not None:
                properties.append(conformer_properties)
            
        average_properties = calculate_average(properties,mode="boltzman_max",weights=weights)
        average_properties_array = np.array(average_properties)

        max_L_index = np.argmax(average_properties_array[:, 0])

        
        filtered_properties =  average_properties[max_L_index]#[prop for prop in properties if prop[0] == max_L]
        results.append({'smiles': smiles, 'L': filtered_properties[0], 'Bmin': filtered_properties[1], 
        'Bmax': filtered_properties[2], 'bur_shell': filtered_properties[3], 'bur_vol': filtered_properties[4], 
        'max_distance': filtered_properties[5], 'tot_V': filtered_properties[6], 'disp': filtered_properties[7],
        'max_axis': filtered_properties[8], 'A2': filtered_properties[9], 'min_axis': filtered_properties[10]})

# Display Sterimol results
results_df = pd.DataFrame(results)

# Save the results to a CSV file
results_csv_file = 'n_boltz_max_sterimol_results.csv'
results_df.to_csv(results_csv_file, index=False)
# Out:
# 0
#    nxyz_files_conf_sample/C=CC[Si](C)(C)C_0conf.xyz / Bmin:  1.70 / Bmax:  6.21 / L:  4.96
#       R/Å     %V_Bur     %S_Bur
#      3.50      33.65       0.00
# 0
#    nxyz_files_conf_sample/C=CC[Si](C)(C)C_1conf.xyz / Bmin:  1.70 / Bmax:  5.44 / L:  6.17
#       R/Å     %V_Bur     %S_Bur
#      3.50      29.09       0.00
# 0
#    nxyz_files_conf_sample/C=CC[Si](C)(C)C_2conf.xyz / Bmin:  1.70 / Bmax:  6.21 / L:  4.96
#       R/Å     %V_Bur     %S_Bur
#      3.50      33.65       0.00
# 0
#    nxyz_files_conf_sample/C=CC[Si](C)(C)C_3conf.xyz / Bmin:  1.70 / Bmax:  5.44 / L:  6.17
#       R/Å     %V_Bur     %S_Bur
#      3.50      29.09       0.00
# 0
#    nxyz_files_conf_sample/C=CC[Si](C)(C)C_4conf.xyz / Bmin:  1.70 / Bmax:  5.44 / L:  6.17
#       R/Å     %V_Bur     %S_Bur
#      3.50      29.09       0.00
# 0
#    nxyz_files_conf_sample/C=CC[Si](C)(C)C_5conf.xyz / Bmin:  1.70 / Bmax:  5.44 / L:  6.17
#       R/Å     %V_Bur     %S_Bur
#      3.50      29.09       0.00
# 0
#    nxyz_files_conf_sample/C=CC[Si](C)(C)C_6conf.xyz / Bmin:  1.70 / Bmax:  5.44 / L:  6.17
#       R/Å     %V_Bur     %S_Bur
#      3.50      29.09       0.00
# 0
#    nxyz_files_conf_sample/C=CC[Si](C)(C)C_7conf.xyz / Bmin:  1.70 / Bmax:  5.44 / L:  6.17
#       R/Å     %V_Bur     %S_Bur
#      3.50      29.09       0.00
# 0
#    nxyz_files_conf_sample/C=CC[Si](C)(C)C_8conf.xyz / Bmin:  1.70 / Bmax:  5.44 / L:  6.17
#       R/Å     %V_Bur     %S_Bur
#      3.50      29.09       0.00
# 0
#    nxyz_files_conf_sample/C=CC[Si](C)(C)C_9conf.xyz / Bmin:  1.70 / Bmax:  6.21 / L:  4.96
#       R/Å     %V_Bur     %S_Bur
#      3.50      33.65       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC)O[Si](C)(C)C(C)(C)C_0conf.xyz / Bmin:  2.90 / Bmax:  6.47 / L:  7.18
#       R/Å     %V_Bur     %S_Bur
#      3.50      33.50       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC)O[Si](C)(C)C(C)(C)C_1conf.xyz / Bmin:  2.90 / Bmax:  6.47 / L:  7.18
#       R/Å     %V_Bur     %S_Bur
#      3.50      33.50       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC)O[Si](C)(C)C(C)(C)C_2conf.xyz / Bmin:  2.90 / Bmax:  6.47 / L:  7.18
#       R/Å     %V_Bur     %S_Bur
#      3.50      33.50       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC)O[Si](C)(C)C(C)(C)C_3conf.xyz / Bmin:  2.57 / Bmax:  6.50 / L:  6.67
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.78       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC)O[Si](C)(C)C(C)(C)C_4conf.xyz / Bmin:  2.86 / Bmax:  5.62 / L:  7.47
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.22       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC)O[Si](C)(C)C(C)(C)C_5conf.xyz / Bmin:  2.90 / Bmax:  6.47 / L:  7.18
#       R/Å     %V_Bur     %S_Bur
#      3.50      33.50       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC)O[Si](C)(C)C(C)(C)C_6conf.xyz / Bmin:  2.90 / Bmax:  6.47 / L:  7.18
#       R/Å     %V_Bur     %S_Bur
#      3.50      33.50       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC)O[Si](C)(C)C(C)(C)C_7conf.xyz / Bmin:  2.57 / Bmax:  6.50 / L:  6.67
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.78       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC)O[Si](C)(C)C(C)(C)C_8conf.xyz / Bmin:  2.90 / Bmax:  6.47 / L:  7.18
#       R/Å     %V_Bur     %S_Bur
#      3.50      33.50       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC)O[Si](C)(C)C(C)(C)C_9conf.xyz / Bmin:  2.51 / Bmax:  5.94 / L:  7.39
#       R/Å     %V_Bur     %S_Bur
#      3.50      36.00       0.00
# 0
#    nxyz_files_conf_sample/C=C(OCc1ccccc1)O[Si](C)(C)C(C)(C)C_0conf.xyz / Bmin:  3.09 / Bmax:  7.33 / L:  6.70
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.58       0.00
# 0
#    nxyz_files_conf_sample/C=C(OCc1ccccc1)O[Si](C)(C)C(C)(C)C_1conf.xyz / Bmin:  3.21 / Bmax:  7.30 / L:  6.76
#       R/Å     %V_Bur     %S_Bur
#      3.50      36.51       0.00
# 0
#    nxyz_files_conf_sample/C=C(OCc1ccccc1)O[Si](C)(C)C(C)(C)C_2conf.xyz / Bmin:  3.09 / Bmax:  7.33 / L:  6.70
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.58       0.00
# 0
#    nxyz_files_conf_sample/C=C(OCc1ccccc1)O[Si](C)(C)C(C)(C)C_3conf.xyz / Bmin:  3.09 / Bmax:  7.33 / L:  6.70
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.58       0.00
# 0
#    nxyz_files_conf_sample/C=C(OCc1ccccc1)O[Si](C)(C)C(C)(C)C_4conf.xyz / Bmin:  3.09 / Bmax:  7.33 / L:  6.70
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.58       0.00
# 0
#    nxyz_files_conf_sample/C=C(OCc1ccccc1)O[Si](C)(C)C(C)(C)C_5conf.xyz / Bmin:  3.49 / Bmax:  7.18 / L:  7.20
#       R/Å     %V_Bur     %S_Bur
#      3.50      33.47       0.00
# 0
#    nxyz_files_conf_sample/C=C(OCc1ccccc1)O[Si](C)(C)C(C)(C)C_6conf.xyz / Bmin:  3.09 / Bmax:  7.33 / L:  6.70
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.58       0.00
# 0
#    nxyz_files_conf_sample/C=C(OCc1ccccc1)O[Si](C)(C)C(C)(C)C_7conf.xyz / Bmin:  2.88 / Bmax:  7.50 / L:  7.44
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.33       0.00
# 0
#    nxyz_files_conf_sample/C=C(OCc1ccccc1)O[Si](C)(C)C(C)(C)C_8conf.xyz / Bmin:  2.85 / Bmax:  7.46 / L:  7.16
#       R/Å     %V_Bur     %S_Bur
#      3.50      36.81       0.00
# 0
#    nxyz_files_conf_sample/C=C(OCc1ccccc1)O[Si](C)(C)C(C)(C)C_9conf.xyz / Bmin:  3.09 / Bmax:  7.33 / L:  6.70
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.58       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC1CCCCC1)O[Si](C)(C)C(C)(C)C_0conf.xyz / Bmin:  3.27 / Bmax:  7.43 / L:  7.18
#       R/Å     %V_Bur     %S_Bur
#      3.50      35.61       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC1CCCCC1)O[Si](C)(C)C(C)(C)C_1conf.xyz / Bmin:  3.30 / Bmax:  7.33 / L:  7.18
#       R/Å     %V_Bur     %S_Bur
#      3.50      35.67       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC1CCCCC1)O[Si](C)(C)C(C)(C)C_2conf.xyz / Bmin:  3.27 / Bmax:  7.43 / L:  7.18
#       R/Å     %V_Bur     %S_Bur
#      3.50      35.61       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC1CCCCC1)O[Si](C)(C)C(C)(C)C_3conf.xyz / Bmin:  3.09 / Bmax:  6.63 / L:  6.59
#       R/Å     %V_Bur     %S_Bur
#      3.50      36.40       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC1CCCCC1)O[Si](C)(C)C(C)(C)C_4conf.xyz / Bmin:  3.18 / Bmax:  7.01 / L:  7.08
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.30       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC1CCCCC1)O[Si](C)(C)C(C)(C)C_5conf.xyz / Bmin:  3.30 / Bmax:  7.33 / L:  7.18
#       R/Å     %V_Bur     %S_Bur
#      3.50      35.67       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC1CCCCC1)O[Si](C)(C)C(C)(C)C_6conf.xyz / Bmin:  3.29 / Bmax:  7.10 / L:  7.18
#       R/Å     %V_Bur     %S_Bur
#      3.50      35.76       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC1CCCCC1)O[Si](C)(C)C(C)(C)C_7conf.xyz / Bmin:  3.27 / Bmax:  7.43 / L:  7.18
#       R/Å     %V_Bur     %S_Bur
#      3.50      35.61       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC1CCCCC1)O[Si](C)(C)C(C)(C)C_8conf.xyz / Bmin:  3.16 / Bmax:  6.92 / L:  7.48
#       R/Å     %V_Bur     %S_Bur
#      3.50      39.30       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC1CCCCC1)O[Si](C)(C)C(C)(C)C_9conf.xyz / Bmin:
#       R/Å     %V_Bur     %S_Bur
#      3.50      35.50       0.00
# 0
#    nxyz_files_conf_sample/C=C(C)C1=CCCCC1_7conf.xyz / Bmin:  2.14 / Bmax:  5.78 / L:  6.11
#       R/Å     %V_Bur     %S_Bur
#      3.50      35.50       0.00
# 0
#    nxyz_files_conf_sample/C=C(C)C1=CCCCC1_8conf.xyz / Bmin:  2.14 / Bmax:  5.78 / L:  6.11
#       R/Å     %V_Bur     %S_Bur
#      3.50      35.50       0.00
# 0
#    nxyz_files_conf_sample/C=C(C)C1=CCCCC1_9conf.xyz / Bmin:  2.23 / Bmax:  5.63 / L:  5.82
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.76       0.00
# 0
#    nxyz_files_conf_sample/C=C(_C=C_C(C)(C)C)C(C)(C)C_0conf.xyz / Bmin:  3.27 / Bmax:  6.30 / L:  6.61
#       R/Å     %V_Bur     %S_Bur
#      3.50      38.41       0.00
# 0
#    nxyz_files_conf_sample/C=C(_C=C_C(C)(C)C)C(C)(C)C_1conf.xyz / Bmin:  3.27 / Bmax:  6.30 / L:  6.61
#       R/Å     %V_Bur     %S_Bur
#      3.50      38.41       0.00
# 0
#    nxyz_files_conf_sample/C=C(_C=C_C(C)(C)C)C(C)(C)C_2conf.xyz / Bmin:  3.27 / Bmax:  6.30 / L:  6.61
#       R/Å     %V_Bur     %S_Bur
#      3.50      38.41       0.00
# 0
#    nxyz_files_conf_sample/C=C(_C=C_C(C)(C)C)C(C)(C)C_3conf.xyz / Bmin:  3.27 / Bmax:  6.30 / L:  6.61
#       R/Å     %V_Bur     %S_Bur
#      3.50      38.41       0.00
# 0
#    nxyz_files_conf_sample/C=C(_C=C_C(C)(C)C)C(C)(C)C_4conf.xyz / Bmin:  3.27 / Bmax:  6.30 / L:  6.61
#       R/Å     %V_Bur     %S_Bur
#      3.50      38.41       0.00
# 0
#    nxyz_files_conf_sample/C=C(_C=C_C(C)(C)C)C(C)(C)C_5conf.xyz / Bmin:  3.27 / Bmax:  6.30 / L:  6.61
#       R/Å     %V_Bur     %S_Bur
#      3.50      38.41       0.00
# 0
#    nxyz_files_conf_sample/C=C(_C=C_C(C)(C)C)C(C)(C)C_6conf.xyz / Bmin:  3.27 / Bmax:  6.30 / L:  6.61
#       R/Å     %V_Bur     %S_Bur
#      3.50      38.41       0.00
# 0
#    nxyz_files_conf_sample/C=C(_C=C_C(C)(C)C)C(C)(C)C_7conf.xyz / Bmin:  3.27 / Bmax:  6.30 / L:  6.61
#       R/Å     %V_Bur     %S_Bur
#      3.50      38.41       0.00
# 0
#    nxyz_files_conf_sample/C=C(_C=C_C(C)(C)C)C(C)(C)C_8conf.xyz / Bmin:  3.27 / Bmax:  6.30 / L:  6.61
#       R/Å     %V_Bur     %S_Bur
#      3.50      38.41       0.00
# 0
#    nxyz_files_conf_sample/C=C(_C=C_C(C)(C)C)C(C)(C)C_9conf.xyz / Bmin:  3.27 / Bmax:  6.30 / L:  6.61
#       R/Å     %V_Bur     %S_Bur
#      3.50      38.41       0.00
# 0
#    nxyz_files_conf_sample/C=C(C)_C=C_CCOCc1ccccc1_0conf.xyz / Bmin:  1.99 / Bmax:  8.31 / L: 11.32
#       R/Å     %V_Bur     %S_Bur
#      3.50      31.48       0.00
# 0
#    nxyz_files_conf_sample/C=C(C)_C=C_CCOCc1ccccc1_1conf.xyz / Bmin:  1.98 / Bmax: 11.00 / L: 10.03
#       R/Å     %V_Bur     %S_Bur
#      3.50      31.48       0.00
# 0
#    nxyz_files_conf_sample/C=C(C)_C=C_CCOCc1ccccc1_2conf.xyz / Bmin:  2.01 / Bmax: 10.32 / L:  8.28
#       R/Å     %V_Bur     %S_Bur
#      3.50      31.48       0.00
# 0
#    nxyz_files_conf_sample/C=C(C)_C=C_CCOCc1ccccc1_3conf.xyz / Bmin:  2.01 / Bmax: 11.05 / L:  9.18
#       R/Å     %V_Bur     %S_Bur
#      3.50      31.50       0.00
# 0
#    nxyz_files_conf_sample/C=C(C)_C=C_CCOCc1ccccc1_4conf.xyz / Bmin:  1.99 / Bmax: 10.53 / L: 11.30
#       R/Å     %V_Bur     %S_Bur
#      3.50      31.48       0.00
# 0
#    nxyz_files_conf_sample/C=C(C)_C=C_CCOCc1ccccc1_5conf.xyz / Bmin:  1.99 / Bmax:  8.31 / L: 11.32
#       R/Å     %V_Bur     %S_Bur
#      3.50      31.48       0.00
# 0
#    nxyz_files_conf_sample/C=C(C)_C=C_CCOCc1ccccc1_6conf.xyz / Bmin:  2.01 / Bmax: 11.05 / L:  9.18
#       R/Å     %V_Bur     %S_Bur
#      3.50      31.50       0.00
# 0
#    nxyz_files_conf_sample/C=C(C)_C=C_CCOCc1ccccc1_7conf.xyz / Bmin:  2.57 / Bmax:  5.20 / L: 12.32
#       R/Å     %V_Bur     %S_Bur
#      3.50      31.47       0.00
# 0
#    nxyz_files_conf_sample/C=C(C)_C=C_CCOCc1ccccc1_8conf.xyz / Bmin:  1.98 / Bmax:  6.87 / L:  8.18
#       R/Å     %V_Bur     %S_Bur
#      3.50      31.48       0.00
# 0
#    nxyz_files_conf_sample/C=C(C)_C=C_CCOCc1ccccc1_9conf.xyz / Bmin:  1.98 / Bmax: 11.00 / L: 10.03
#       R/Å     %V_Bur     %S_Bur
#      3.50      31.48       0.00
# 0
#    nxyz_files_conf_sample/C1=CCC=C1_0conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 1
#    nxyz_files_conf_sample/C1=CCC=C1_0conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 3
#    nxyz_files_conf_sample/C1=CCC=C1_0conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 4
#    nxyz_files_conf_sample/C1=CCC=C1_0conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 0
#    nxyz_files_conf_sample/C1=CCC=C1_1conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 1
#    nxyz_files_conf_sample/C1=CCC=C1_1conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 3
#    nxyz_files_conf_sample/C1=CCC=C1_1conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 4
#    nxyz_files_conf_sample/C1=CCC=C1_1conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 0
#    nxyz_files_conf_sample/C1=CCC=C1_2conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 1
#    nxyz_files_conf_sample/C1=CCC=C1_2conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 3
#    nxyz_files_conf_sample/C1=CCC=C1_2conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 4
#    nxyz_files_conf_sample/C1=CCC=C1_2conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 0
#    nxyz_files_conf_sample/C1=CCC=C1_3conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 1
#    nxyz_files_conf_sample/C1=CCC=C1_3conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 3
#    nxyz_files_conf_sample/C1=CCC=C1_3conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 4
#    nxyz_files_conf_sample/C1=CCC=C1_3conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 0
#    nxyz_files_conf_sample/C1=CCC=C1_4conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 1
#    nxyz_files_conf_sample/C1=CCC=C1_4conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 3
#    nxyz_files_conf_sample/C1=CCC=C1_4conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 4
#    nxyz_files_conf_sample/C1=CCC=C1_4conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 0
#    nxyz_files_conf_sample/C1=CCC=C1_5conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 1
#    nxyz_files_conf_sample/C1=CCC=C1_5conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 3
#    nxyz_files_conf_sample/C1=CCC=C1_5conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 4
#    nxyz_files_conf_sample/C1=CCC=C1_5conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 0
#    nxyz_files_conf_sample/C1=CCC=C1_6conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 1
#    nxyz_files_conf_sample/C1=CCC=C1_6conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 3
#    nxyz_files_conf_sample/C1=CCC=C1_6conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 4
#    nxyz_files_conf_sample/C1=CCC=C1_6conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 0
#    nxyz_files_conf_sample/C1=CCC=C1_7conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 1
#    nxyz_files_conf_sample/C1=CCC=C1_7conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 3
#    nxyz_files_conf_sample/C1=CCC=C1_7conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 4
#    nxyz_files_conf_sample/C1=CCC=C1_7conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 0
#    nxyz_files_conf_sample/C1=CCC=C1_8conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 1
#    nxyz_files_conf_sample/C1=CCC=C1_8conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 3
#    nxyz_files_conf_sample/C1=CCC=C1_8conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 4
#    nxyz_files_conf_sample/C1=CCC=C1_8conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 0
#    nxyz_files_conf_sample/C1=CCC=C1_9conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 1
#    nxyz_files_conf_sample/C1=CCC=C1_9conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 3
#    nxyz_files_conf_sample/C1=CCC=C1_9conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 4
#    nxyz_files_conf_sample/C1=CCC=C1_9conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 0
#    nxyz_files_conf_sample/C1=CCCC=C1_0conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 1
#    nxyz_files_conf_sample/C1=CCCC=C1_0conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 4
#    nxyz_files_conf_sample/C1=CCCC=C1_0conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 5
#    nxyz_files_conf_sample/C1=CCCC=C1_0conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 0
#    nxyz_files_conf_sample/C1=CCCC=C1_1conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 1
#    nxyz_files_conf_sample/C1=CCCC=C1_1conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 4
#    nxyz_files_conf_sample/C1=CCCC=C1_1conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 5
#    nxyz_files_conf_sample/C1=CCCC=C1_1conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 0
#    nxyz_files_conf_sample/C1=CCCC=C1_2conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 1
#    nxyz_files_conf_sample/C1=CCCC=C1_2conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 4
#    nxyz_files_conf_sample/C1=CCCC=C1_2conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 5
#    nxyz_files_conf_sample/C1=CCCC=C1_2conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 0
#    nxyz_files_conf_sample/C1=CCCC=C1_3conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 1
#    nxyz_files_conf_sample/C1=CCCC=C1_3conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 4
#    nxyz_files_conf_sample/C1=CCCC=C1_3conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 5
#    nxyz_files_conf_sample/C1=CCCC=C1_3conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 0
#    nxyz_files_conf_sample/C1=CCCC=C1_4conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 1
#    nxyz_files_conf_sample/C1=CCCC=C1_4conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 4
#    nxyz_files_conf_sample/C1=CCCC=C1_4conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 5
#    nxyz_files_conf_sample/C1=CCCC=C1_4conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 0
#    nxyz_files_conf_sample/C1=CCCC=C1_5conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 1
#    nxyz_files_conf_sample/C1=CCCC=C1_5conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 4
#    nxyz_files_conf_sample/C1=CCCC=C1_5conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 5
#    nxyz_files_conf_sample/C1=CCCC=C1_5conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 0
#    nxyz_files_conf_sample/C1=CCCC=C1_6conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 1
#    nxyz_files_conf_sample/C1=CCCC=C1_6conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 4
#    nxyz_files_conf_sample/C1=CCCC=C1_6conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 5
#    nxyz_files_conf_sample/C1=CCCC=C1_6conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 0
#    nxyz_files_conf_sample/C1=CCCC=C1_7conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 1
#    nxyz_files_conf_sample/C1=CCCC=C1_7conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 4
#    nxyz_files_conf_sample/C1=CCCC=C1_7conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 5
#    nxyz_files_conf_sample/C1=CCCC=C1_7conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 0
#    nxyz_files_conf_sample/C1=CCCC=C1_8conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 1
#    nxyz_files_conf_sample/C1=CCCC=C1_8conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 4
#    nxyz_files_conf_sample/C1=CCCC=C1_8conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 5
#    nxyz_files_conf_sample/C1=CCCC=C1_8conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 0
#    nxyz_files_conf_sample/C1=CCCC=C1_9conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 1
#    nxyz_files_conf_sample/C1=CCCC=C1_9conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 4
#    nxyz_files_conf_sample/C1=CCCC=C1_9conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 5
#    nxyz_files_conf_sample/C1=CCCC=C1_9conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00

# %%
electrophiles_to_delete = ['ClC1CCCO1','Cc4ccc(S(=O)(=O)N3CC(/C=C/c1ccccc1)c2ccccc23)cc4']

results_csv_file = 'boltz_weighted_sterimol_results.csv'
sterimol_df = pd.read_csv(results_csv_file)
sterimol_df["input electrophile SMILES"]=  sterimol_df["smiles"]
# Load additional information from the second CSV file
nresults_csv_file = 'n_boltz_weighted_sterimol_results.csv'
nsterimol_df = pd.read_csv(nresults_csv_file)
nsterimol_df["nucleophile SMILES"]=  nsterimol_df["smiles"]


additional_info_csv_file = 'sterimol/merged.csv'
additional_info_df = pd.read_csv(additional_info_csv_file)

# Merge DataFrames based on the 'SMILES' column
merged_df = pd.merge( additional_info_df, sterimol_df, on='input electrophile SMILES', how='left')
merged_df = pd.merge( merged_df, nsterimol_df, on='nucleophile SMILES', how='left',suffixes=('_e', '_n'))
merged_df = merged_df[~merged_df['input electrophile SMILES'].isin(electrophiles_to_delete)]
# Save the merged DataFrame to a new CSV file
merged_csv_file = 'merged_weighted.csv'
merged_df.to_csv(merged_csv_file, index=False)

print(f"Merged results saved to {merged_csv_file}")
# Out:
# Merged results saved to merged_weighted.csv

# %% [markdown]
# # Boltzman Average conformer method

# %%
unique_df = df1.drop_duplicates(subset='nucleophile SMILES')

# Find Sterimol parameters for each unique SMILES
results = []
for index, row in unique_df.iterrows():
    properties = []
    terminal_double_bonded_carbons = find_terminal_double_bonded_carbons(row['nucleophile SMILES'])
    if terminal_double_bonded_carbons:
        smiles = terminal_double_bonded_carbons['smiles']
        terminal_atom_ids = terminal_double_bonded_carbons['terminal_atoms']
        non_terminal_atoms = terminal_double_bonded_carbons['non_terminal_atoms']
        # Create .xyz file
        output_folder = 'nxyz_files_conf_sample'
        os.makedirs(output_folder, exist_ok=True)
        #output_file_path = os.path.join(output_folder, f'{smiles.replace("/", "_")}.xyz')
        conformers, weights = smiles_to_xyz(smiles, output_folder,'conformer_energy')
        for conf in conformers:
            
            conformer_properties = []
            for i in range(len(terminal_atom_ids)):
                print(terminal_atom_ids[i])
                #L, Bmin,Bmax,bur_shell,bur_vol, max_distance, tot_V, disp,max_axis,A2,min_axis
                props  = run_dbstep(conf, terminal_atom_ids[i], non_terminal_atoms[i])
                if props is not None:
                    conformer_properties.append(props)
            if props is not None:
                properties.append(conformer_properties)
            
        average_properties = calculate_average(properties,mode="boltzman_weighted",weights=weights)
        average_properties_array = np.array(average_properties)

        max_L_index = np.argmax(average_properties_array[:, 0])

        
        filtered_properties =  average_properties[max_L_index]#[prop for prop in properties if prop[0] == max_L]
        print(filtered_properties )
        results.append({'smiles': smiles, 'L': filtered_properties[0], 'Bmin': filtered_properties[1], 
        'Bmax': filtered_properties[2], 'bur_shell': filtered_properties[3], 'bur_vol': filtered_properties[4], 
        'max_distance': filtered_properties[5], 'tot_V': filtered_properties[6], 'disp': filtered_properties[7],
         'max_axis': filtered_properties[8], 'A2': filtered_properties[9], 'min_axis': filtered_properties[10]})

# Display Sterimol results
results_df = pd.DataFrame(results)

# Save the results to a CSV file
results_csv_file = 'n_boltz_weighted_sterimol_results.csv'
results_df.to_csv(results_csv_file, index=False)
# Out:
# 0
#    nxyz_files_conf_sample/C=CC[Si](C)(C)C_0conf.xyz / Bmin:  1.70 / Bmax:  5.44 / L:  6.17
#       R/Å     %V_Bur     %S_Bur
#      3.50      29.09       0.00
# 0
#    nxyz_files_conf_sample/C=CC[Si](C)(C)C_1conf.xyz / Bmin:  1.70 / Bmax:  5.44 / L:  6.17
#       R/Å     %V_Bur     %S_Bur
#      3.50      29.09       0.00
# 0
#    nxyz_files_conf_sample/C=CC[Si](C)(C)C_2conf.xyz / Bmin:  1.70 / Bmax:  5.44 / L:  6.17
#       R/Å     %V_Bur     %S_Bur
#      3.50      29.09       0.00
# 0
#    nxyz_files_conf_sample/C=CC[Si](C)(C)C_3conf.xyz / Bmin:  1.70 / Bmax:  6.21 / L:  4.96
#       R/Å     %V_Bur     %S_Bur
#      3.50      33.65       0.00
# 0
#    nxyz_files_conf_sample/C=CC[Si](C)(C)C_4conf.xyz / Bmin:  1.70 / Bmax:  5.44 / L:  6.17
#       R/Å     %V_Bur     %S_Bur
#      3.50      29.09       0.00
# 0
#    nxyz_files_conf_sample/C=CC[Si](C)(C)C_5conf.xyz / Bmin:  1.70 / Bmax:  5.44 / L:  6.17
#       R/Å     %V_Bur     %S_Bur
#      3.50      29.09       0.00
# 0
#    nxyz_files_conf_sample/C=CC[Si](C)(C)C_6conf.xyz / Bmin:  1.70 / Bmax:  6.21 / L:  4.96
#       R/Å     %V_Bur     %S_Bur
#      3.50      33.65       0.00
# 0
#    nxyz_files_conf_sample/C=CC[Si](C)(C)C_7conf.xyz / Bmin:  1.70 / Bmax:  5.44 / L:  6.17
#       R/Å     %V_Bur     %S_Bur
#      3.50      29.09       0.00
# 0
#    nxyz_files_conf_sample/C=CC[Si](C)(C)C_8conf.xyz / Bmin:  1.70 / Bmax:  5.44 / L:  6.17
#       R/Å     %V_Bur     %S_Bur
#      3.50      29.09       0.00
# 0
#    nxyz_files_conf_sample/C=CC[Si](C)(C)C_9conf.xyz / Bmin:  1.70 / Bmax:  5.44 / L:  6.17
#       R/Å     %V_Bur     %S_Bur
#      3.50      29.09       0.00
# [6.16963715999642, 1.7000000000000008, 5.437510319695459, 0.0, 29.089383685643885, 7.2044644144937715, 135.07500099085652, 3.2440090839992797, 7.051193889479687, 0.6776785417525614, 0.5685429449776626]
# 0
#    nxyz_files_conf_sample/C=C(OC)O[Si](C)(C)C(C)(C)C_0conf.xyz / Bmin:  2.86 / Bmax:  5.62 / L:  7.47
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.22       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC)O[Si](C)(C)C(C)(C)C_1conf.xyz / Bmin:  2.90 / Bmax:  6.47 / L:  7.18
#       R/Å     %V_Bur     %S_Bur
#      3.50      33.50       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC)O[Si](C)(C)C(C)(C)C_2conf.xyz / Bmin:  2.86 / Bmax:  5.62 / L:  7.47
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.22       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC)O[Si](C)(C)C(C)(C)C_3conf.xyz / Bmin:  2.57 / Bmax:  6.50 / L:  6.67
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.78       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC)O[Si](C)(C)C(C)(C)C_4conf.xyz / Bmin:  2.86 / Bmax:  5.62 / L:  7.47
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.22       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC)O[Si](C)(C)C(C)(C)C_5conf.xyz / Bmin:  2.57 / Bmax:  6.50 / L:  6.67
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.78       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC)O[Si](C)(C)C(C)(C)C_6conf.xyz / Bmin:  2.57 / Bmax:  6.50 / L:  6.67
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.78       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC)O[Si](C)(C)C(C)(C)C_7conf.xyz / Bmin:  2.57 / Bmax:  6.50 / L:  6.67
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.78       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC)O[Si](C)(C)C(C)(C)C_8conf.xyz / Bmin:  2.57 / Bmax:  6.50 / L:  6.67
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.78       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC)O[Si](C)(C)C(C)(C)C_9conf.xyz / Bmin:  2.90 / Bmax:  6.47 / L:  7.18
#       R/Å     %V_Bur     %S_Bur
#      3.50      33.50       0.00
# [7.141998742561872, 2.865604849866472, 6.4227235755619745, 0.0, 33.668792122053155, 8.755992754023179, 221.93709204891027, 4.661170070345602, 8.676644489891784, 0.6015664523974447, 0.5692135317248742]
# 0
#    nxyz_files_conf_sample/C=C(OCc1ccccc1)O[Si](C)(C)C(C)(C)C_0conf.xyz / Bmin:  3.49 / Bmax:  7.18 / L:  7.20
#       R/Å     %V_Bur     %S_Bur
#      3.50      33.47       0.00
# 0
#    nxyz_files_conf_sample/C=C(OCc1ccccc1)O[Si](C)(C)C(C)(C)C_1conf.xyz / Bmin:  3.09 / Bmax:  7.33 / L:  6.70
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.58       0.00
# 0
#    nxyz_files_conf_sample/C=C(OCc1ccccc1)O[Si](C)(C)C(C)(C)C_2conf.xyz / Bmin:  3.49 / Bmax:  7.18 / L:  7.20
#       R/Å     %V_Bur     %S_Bur
#      3.50      33.47       0.00
# 0
#    nxyz_files_conf_sample/C=C(OCc1ccccc1)O[Si](C)(C)C(C)(C)C_3conf.xyz / Bmin:  2.87 / Bmax:  7.50 / L:  7.44
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.33       0.00
# 0
#    nxyz_files_conf_sample/C=C(OCc1ccccc1)O[Si](C)(C)C(C)(C)C_4conf.xyz / Bmin:  2.85 / Bmax:  7.46 / L:  7.16
#       R/Å     %V_Bur     %S_Bur
#      3.50      36.81       0.00
# 0
#    nxyz_files_conf_sample/C=C(OCc1ccccc1)O[Si](C)(C)C(C)(C)C_5conf.xyz / Bmin:  3.09 / Bmax:  7.33 / L:  6.70
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.58       0.00
# 0
#    nxyz_files_conf_sample/C=C(OCc1ccccc1)O[Si](C)(C)C(C)(C)C_6conf.xyz / Bmin:  2.85 / Bmax:  7.46 / L:  7.16
#       R/Å     %V_Bur     %S_Bur
#      3.50      36.81       0.00
# 0
#    nxyz_files_conf_sample/C=C(OCc1ccccc1)O[Si](C)(C)C(C)(C)C_7conf.xyz / Bmin:  3.09 / Bmax:  7.33 / L:  6.70
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.58       0.00
# 0
#    nxyz_files_conf_sample/C=C(OCc1ccccc1)O[Si](C)(C)C(C)(C)C_8conf.xyz / Bmin:  3.09 / Bmax:  7.33 / L:  6.70
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.58       0.00
# 0
#    nxyz_files_conf_sample/C=C(OCc1ccccc1)O[Si](C)(C)C(C)(C)C_9conf.xyz / Bmin:  3.21 / Bmax:  7.30 / L:  6.76
#       R/Å     %V_Bur     %S_Bur
#      3.50      36.50       0.00
# [7.19999523, 3.491493244826951, 7.182483372439103, 0.0, 33.46655127300882, 11.542826749376793, 355.17921413530377, 8.337056546858054, 11.241248596860043, 0.5748605210401431, 0.4349520691088332]
# 0
#    nxyz_files_conf_sample/C=C(OC1CCCCC1)O[Si](C)(C)C(C)(C)C_0conf.xyz / Bmin:  3.32 / Bmax:  6.91 / L:  7.14
#       R/Å     %V_Bur     %S_Bur
#      3.50      39.43       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC1CCCCC1)O[Si](C)(C)C(C)(C)C_1conf.xyz / Bmin:  3.05 / Bmax:  6.58 / L:  6.77
#       R/Å     %V_Bur     %S_Bur
#      3.50      36.25       0.00
# 0
#    nxyz_files_conf_sample/C=C(OC1CCCCC1)O[Si](C)(C)C(C)(C)C_2conf.xyz / Bmin:
# 0
#    nxyz_files_conf_sample/C1=CCC=C1_0conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 1
#    nxyz_files_conf_sample/C1=CCC=C1_0conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 3
#    nxyz_files_conf_sample/C1=CCC=C1_0conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 4
#    nxyz_files_conf_sample/C1=CCC=C1_0conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 0
#    nxyz_files_conf_sample/C1=CCC=C1_1conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 1
#    nxyz_files_conf_sample/C1=CCC=C1_1conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 3
#    nxyz_files_conf_sample/C1=CCC=C1_1conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 4
#    nxyz_files_conf_sample/C1=CCC=C1_1conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 0
#    nxyz_files_conf_sample/C1=CCC=C1_2conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 1
#    nxyz_files_conf_sample/C1=CCC=C1_2conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 3
#    nxyz_files_conf_sample/C1=CCC=C1_2conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 4
#    nxyz_files_conf_sample/C1=CCC=C1_2conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 0
#    nxyz_files_conf_sample/C1=CCC=C1_3conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 1
#    nxyz_files_conf_sample/C1=CCC=C1_3conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 3
#    nxyz_files_conf_sample/C1=CCC=C1_3conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 4
#    nxyz_files_conf_sample/C1=CCC=C1_3conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 0
#    nxyz_files_conf_sample/C1=CCC=C1_4conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 1
#    nxyz_files_conf_sample/C1=CCC=C1_4conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 3
#    nxyz_files_conf_sample/C1=CCC=C1_4conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 4
#    nxyz_files_conf_sample/C1=CCC=C1_4conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 0
#    nxyz_files_conf_sample/C1=CCC=C1_5conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 1
#    nxyz_files_conf_sample/C1=CCC=C1_5conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 3
#    nxyz_files_conf_sample/C1=CCC=C1_5conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 4
#    nxyz_files_conf_sample/C1=CCC=C1_5conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 0
#    nxyz_files_conf_sample/C1=CCC=C1_6conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 1
#    nxyz_files_conf_sample/C1=CCC=C1_6conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 3
#    nxyz_files_conf_sample/C1=CCC=C1_6conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 4
#    nxyz_files_conf_sample/C1=CCC=C1_6conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 0
#    nxyz_files_conf_sample/C1=CCC=C1_7conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 1
#    nxyz_files_conf_sample/C1=CCC=C1_7conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 3
#    nxyz_files_conf_sample/C1=CCC=C1_7conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 4
#    nxyz_files_conf_sample/C1=CCC=C1_7conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 0
#    nxyz_files_conf_sample/C1=CCC=C1_8conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 1
#    nxyz_files_conf_sample/C1=CCC=C1_8conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 3
#    nxyz_files_conf_sample/C1=CCC=C1_8conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 4
#    nxyz_files_conf_sample/C1=CCC=C1_8conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 0
#    nxyz_files_conf_sample/C1=CCC=C1_9conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 1
#    nxyz_files_conf_sample/C1=CCC=C1_9conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 3
#    nxyz_files_conf_sample/C1=CCC=C1_9conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.95
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# 4
#    nxyz_files_conf_sample/C1=CCC=C1_9conf.xyz / Bmin:  1.70 / Bmax:  4.36 / L:  3.55
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.65       0.00
# [3.950992459999969, 1.6999999999999993, 4.364413100000043, 0.0, 34.647960870944765, 4.400311548801183, 29.40585152028629, 3.1888570261315423, 4.400311548799865, 0.8480622320923865, 0.40696378002604644]
# 0
#    nxyz_files_conf_sample/C1=CCCC=C1_0conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 1
#    nxyz_files_conf_sample/C1=CCCC=C1_0conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 4
#    nxyz_files_conf_sample/C1=CCCC=C1_0conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 5
#    nxyz_files_conf_sample/C1=CCCC=C1_0conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 0
#    nxyz_files_conf_sample/C1=CCCC=C1_1conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 1
#    nxyz_files_conf_sample/C1=CCCC=C1_1conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 4
#    nxyz_files_conf_sample/C1=CCCC=C1_1conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 5
#    nxyz_files_conf_sample/C1=CCCC=C1_1conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 0
#    nxyz_files_conf_sample/C1=CCCC=C1_2conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 1
#    nxyz_files_conf_sample/C1=CCCC=C1_2conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 4
#    nxyz_files_conf_sample/C1=CCCC=C1_2conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 5
#    nxyz_files_conf_sample/C1=CCCC=C1_2conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 0
#    nxyz_files_conf_sample/C1=CCCC=C1_3conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 1
#    nxyz_files_conf_sample/C1=CCCC=C1_3conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 4
#    nxyz_files_conf_sample/C1=CCCC=C1_3conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 5
#    nxyz_files_conf_sample/C1=CCCC=C1_3conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 0
#    nxyz_files_conf_sample/C1=CCCC=C1_4conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 1
#    nxyz_files_conf_sample/C1=CCCC=C1_4conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 4
#    nxyz_files_conf_sample/C1=CCCC=C1_4conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 5
#    nxyz_files_conf_sample/C1=CCCC=C1_4conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 0
#    nxyz_files_conf_sample/C1=CCCC=C1_5conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 1
#    nxyz_files_conf_sample/C1=CCCC=C1_5conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 4
#    nxyz_files_conf_sample/C1=CCCC=C1_5conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 5
#    nxyz_files_conf_sample/C1=CCCC=C1_5conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 0
#    nxyz_files_conf_sample/C1=CCCC=C1_6conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 1
#    nxyz_files_conf_sample/C1=CCCC=C1_6conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 4
#    nxyz_files_conf_sample/C1=CCCC=C1_6conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 5
#    nxyz_files_conf_sample/C1=CCCC=C1_6conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 0
#    nxyz_files_conf_sample/C1=CCCC=C1_7conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 1
#    nxyz_files_conf_sample/C1=CCCC=C1_7conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 4
#    nxyz_files_conf_sample/C1=CCCC=C1_7conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 5
#    nxyz_files_conf_sample/C1=CCCC=C1_7conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 0
#    nxyz_files_conf_sample/C1=CCCC=C1_8conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 1
#    nxyz_files_conf_sample/C1=CCCC=C1_8conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 4
#    nxyz_files_conf_sample/C1=CCCC=C1_8conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 5
#    nxyz_files_conf_sample/C1=CCCC=C1_8conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 0
#    nxyz_files_conf_sample/C1=CCCC=C1_9conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 1
#    nxyz_files_conf_sample/C1=CCCC=C1_9conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 4
#    nxyz_files_conf_sample/C1=CCCC=C1_9conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# 5
#    nxyz_files_conf_sample/C1=CCCC=C1_9conf.xyz / Bmin:  1.70 / Bmax:  4.46 / L:  4.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.17       0.00
# [4.2603824999999915, 1.7, 4.458729814844862, 0.0, 37.17308435421021, 5.011868025002895, 44.65374016011049, 2.2319208929256207, 5.009451101276003, 0.8244135001512972, 0.43086609524182284]

# %%
unique_df = df1.drop_duplicates(subset='input electrophile SMILES')

# Find Sterimol parameters for each unique SMILES
results = []
for index, row in unique_df.iterrows():
    properties = []
    c_o_info = find_c_o_atom_ids(row['input electrophile SMILES'])
    if c_o_info:
        smiles = c_o_info['smiles']
        oxygen_atom_id = c_o_info['oxygen_atom_ids']
        carbon_atom_id = c_o_info['carbon_atom_ids']

        # Create .xyz file
        output_folder = 'exyz_files_conf_sample'
        os.makedirs(output_folder, exist_ok=True)
        conformers, weights = smiles_to_xyz(smiles, output_folder,'conformer_energy')
        for conf in conformers:
            
            conformer_properties = []
            for i in range(len(oxygen_atom_id)):
                print(oxygen_atom_id[i])
                #L, Bmin,Bmax,bur_shell,bur_vol, max_distance, tot_V, disp,max_axis,A2,min_axis
                props  = run_dbstep(conf, oxygen_atom_id[i], carbon_atom_id[i])
                if props is not None:
                    conformer_properties.append(props)
            if props is not None:
                properties.append(conformer_properties)
            

        
        average_properties_array = calculate_average(properties,mode="boltzman_weighted",weights=weights)[0]
        #average_properties_array = np.array(average_properties)

       
        results.append({'smiles': smiles, 'L': average_properties_array[0], 'Bmin': average_properties_array[1], 
        'Bmax': average_properties_array[2], 'bur_shell': average_properties_array[3], 'bur_vol': average_properties_array[4], 
        'max_distance': average_properties_array[5], 'tot_V': average_properties_array[6], 'disp': average_properties_array[7],
         'max_axis': average_properties_array[8], 'A2': average_properties_array[9], 'min_axis': average_properties_array[10]})


# Display Sterimol results
results_df = pd.DataFrame(results)

# Save the results to a CSV file
results_csv_file = 'boltz_weighted_sterimol_results.csv'
results_df.to_csv(results_csv_file, index=False)
# Out:
# 0
#    exyz_files_conf_sample/O=Cc2ccc1ccccc1c2_0conf.xyz / Bmin:  1.70 / Bmax:  8.16 / L:  6.44
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.32       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1ccccc1c2_1conf.xyz / Bmin:  1.70 / Bmax:  8.16 / L:  6.44
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.32       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1ccccc1c2_2conf.xyz / Bmin:  1.70 / Bmax:  8.16 / L:  6.44
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.32       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1ccccc1c2_3conf.xyz / Bmin:  1.70 / Bmax:  8.16 / L:  6.44
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.32       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1ccccc1c2_4conf.xyz / Bmin:  1.70 / Bmax:  8.16 / L:  6.44
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.32       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1ccccc1c2_5conf.xyz / Bmin:  1.70 / Bmax:  8.16 / L:  6.44
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.32       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1ccccc1c2_6conf.xyz / Bmin:  1.70 / Bmax:  8.16 / L:  6.44
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.32       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1ccccc1c2_7conf.xyz / Bmin:  1.70 / Bmax:  8.16 / L:  6.44
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.32       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1ccccc1c2_8conf.xyz / Bmin:  1.70 / Bmax:  6.85 / L:  8.50
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.32       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1ccccc1c2_9conf.xyz / Bmin:  1.70 / Bmax:  8.16 / L:  6.44
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.32       0.00
# 9
#    exyz_files_conf_sample/COc2ccc1cc(C=O)ccc1c2_0conf.xyz / Bmin:  1.70 / Bmax:  8.93 / L:  8.49
#       R/Å     %V_Bur     %S_Bur
#      3.50      28.62       0.00
# 9
#    exyz_files_conf_sample/COc2ccc1cc(C=O)ccc1c2_1conf.xyz / Bmin:  1.70 / Bmax: 10.25 / L:  6.43
#       R/Å     %V_Bur     %S_Bur
#      3.50      28.63       0.00
# 9
#    exyz_files_conf_sample/COc2ccc1cc(C=O)ccc1c2_2conf.xyz / Bmin:  1.70 / Bmax: 10.25 / L:  6.43
#       R/Å     %V_Bur     %S_Bur
#      3.50      28.63       0.00
# 9
#    exyz_files_conf_sample/COc2ccc1cc(C=O)ccc1c2_3conf.xyz / Bmin:  1.70 / Bmax:  8.93 / L:  8.49
#       R/Å     %V_Bur     %S_Bur
#      3.50      28.62       0.00
# 9
#    exyz_files_conf_sample/COc2ccc1cc(C=O)ccc1c2_4conf.xyz / Bmin:  1.70 / Bmax:  9.41 / L:  7.37
#       R/Å     %V_Bur     %S_Bur
#      3.50      28.62       0.00
# 9
#    exyz_files_conf_sample/COc2ccc1cc(C=O)ccc1c2_5conf.xyz / Bmin:  1.70 / Bmax:  8.93 / L:  8.49
#       R/Å     %V_Bur     %S_Bur
#      3.50      28.62       0.00
# 9
#    exyz_files_conf_sample/COc2ccc1cc(C=O)ccc1c2_6conf.xyz / Bmin:  1.70 / Bmax:  8.10 / L:  9.43
#       R/Å     %V_Bur     %S_Bur
#      3.50      28.62       0.00
# 9
#    exyz_files_conf_sample/COc2ccc1cc(C=O)ccc1c2_7conf.xyz / Bmin:  1.70 / Bmax:  8.10 / L:  9.43
#       R/Å     %V_Bur     %S_Bur
#      3.50      28.62       0.00
# 9
#    exyz_files_conf_sample/COc2ccc1cc(C=O)ccc1c2_8conf.xyz / Bmin:  1.70 / Bmax:  8.93 / L:  8.49
#       R/Å     %V_Bur     %S_Bur
#      3.50      28.62       0.00
# 9
#    exyz_files_conf_sample/COc2ccc1cc(C=O)ccc1c2_9conf.xyz / Bmin:  1.70 / Bmax:  8.10 / L:  9.43
#       R/Å     %V_Bur     %S_Bur
#      3.50      28.62       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1cc(Br)ccc1c2_0conf.xyz / Bmin:  1.70 / Bmax:  8.15 / L:  8.52
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.33       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1cc(Br)ccc1c2_1conf.xyz / Bmin:  1.70 / Bmax:  8.15 / L:  8.52
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.33       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1cc(Br)ccc1c2_2conf.xyz / Bmin:  1.70 / Bmax:  8.15 / L:  8.52
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.33       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1cc(Br)ccc1c2_3conf.xyz / Bmin:  1.70 / Bmax:  8.15 / L:  8.52
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.33       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1cc(Br)ccc1c2_4conf.xyz / Bmin:  1.70 / Bmax:  8.15 / L:  8.52
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.33       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1cc(Br)ccc1c2_5conf.xyz / Bmin:  1.70 / Bmax:  9.47 / L:  6.45
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.34       0.00
# 0
#    exyz_files_conf_sample/O=Cc2ccc1cc(Br)ccc1c2
f.xyz / Bmin:  1.70 / Bmax:  4.51 / L:  6.12
#       R/Å     %V_Bur     %S_Bur
#      3.50      29.05       0.00
# 5
#    exyz_files_conf_sample/C_C=C(C)_C=O_7conf.xyz / Bmin:  1.70 / Bmax:  4.51 / L:  6.12
#       R/Å     %V_Bur     %S_Bur
#      3.50      29.05       0.00
# 5
#    exyz_files_conf_sample/C_C=C(C)_C=O_8conf.xyz / Bmin:  1.70 / Bmax:  5.52 / L:  5.24
#       R/Å     %V_Bur     %S_Bur
#      3.50      29.14       0.00
# 5
#    exyz_files_conf_sample/C_C=C(C)_C=O_9conf.xyz / Bmin:  1.70 / Bmax:  5.52 / L:  5.24
#       R/Å     %V_Bur     %S_Bur
#      3.50      29.14       0.00
# 0
#    exyz_files_conf_sample/O=CC1=CCCC1_0conf.xyz / Bmin:  1.70 / Bmax:  5.43 / L:  5.83
#       R/Å     %V_Bur     %S_Bur
#      3.50      25.63       0.00
# 0
#    exyz_files_conf_sample/O=CC1=CCCC1_1conf.xyz / Bmin:  1.70 / Bmax:  5.43 / L:  5.83
#       R/Å     %V_Bur     %S_Bur
#      3.50      25.63       0.00
# 0
#    exyz_files_conf_sample/O=CC1=CCCC1_2conf.xyz / Bmin:  1.70 / Bmax:  5.55 / L:  5.70
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.31       0.00
# 0
#    exyz_files_conf_sample/O=CC1=CCCC1_3conf.xyz / Bmin:  1.70 / Bmax:  5.43 / L:  5.83
#       R/Å     %V_Bur     %S_Bur
#      3.50      25.63       0.00
# 0
#    exyz_files_conf_sample/O=CC1=CCCC1_4conf.xyz / Bmin:  1.70 / Bmax:  5.55 / L:  5.70
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.31       0.00
# 0
#    exyz_files_conf_sample/O=CC1=CCCC1_5conf.xyz / Bmin:  1.70 / Bmax:  5.55 / L:  5.70
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.31       0.00
# 0
#    exyz_files_conf_sample/O=CC1=CCCC1_6conf.xyz / Bmin:  1.70 / Bmax:  5.55 / L:  5.70
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.31       0.00
# 0
#    exyz_files_conf_sample/O=CC1=CCCC1_7conf.xyz / Bmin:  1.70 / Bmax:  5.43 / L:  5.83
#       R/Å     %V_Bur     %S_Bur
#      3.50      25.63       0.00
# 0
#    exyz_files_conf_sample/O=CC1=CCCC1_8conf.xyz / Bmin:  1.70 / Bmax:  5.43 / L:  5.83
#       R/Å     %V_Bur     %S_Bur
#      3.50      25.63       0.00
# 0
#    exyz_files_conf_sample/O=CC1=CCCC1_9conf.xyz / Bmin:  1.70 / Bmax:  5.43 / L:  5.83
#       R/Å     %V_Bur     %S_Bur
#      3.50      25.63       0.00
# 3
#    exyz_files_conf_sample/C=CC=O_0conf.xyz / Bmin:  1.70 / Bmax:  3.27 / L:  5.03
#       R/Å     %V_Bur     %S_Bur
#      3.50      25.84       0.00
# 3
#    exyz_files_conf_sample/C=CC=O_1conf.xyz / Bmin:  1.70 / Bmax:  4.43 / L:  4.21
#       R/Å     %V_Bur     %S_Bur
#      3.50      27.17       0.00
# 3
#    exyz_files_conf_sample/C=CC=O_2conf.xyz / Bmin:  1.70 / Bmax:  4.43 / L:  4.21
#       R/Å     %V_Bur     %S_Bur
#      3.50      27.17       0.00
# 3
#    exyz_files_conf_sample/C=CC=O_3conf.xyz / Bmin:  1.70 / Bmax:  4.43 / L:  4.21
#       R/Å     %V_Bur     %S_Bur
#      3.50      27.17       0.00
# 3
#    exyz_files_conf_sample/C=CC=O_4conf.xyz / Bmin:  1.70 / Bmax:  3.27 / L:  5.03
#       R/Å     %V_Bur     %S_Bur
#      3.50      25.84       0.00
# 3
#    exyz_files_conf_sample/C=CC=O_5conf.xyz / Bmin:  1.70 / Bmax:  3.27 / L:  5.03
#       R/Å     %V_Bur     %S_Bur
#      3.50      25.84       0.00
# 3
#    exyz_files_conf_sample/C=CC=O_6conf.xyz / Bmin:  1.70 / Bmax:  3.27 / L:  5.03
#       R/Å     %V_Bur     %S_Bur
#      3.50      25.84       0.00
# 3
#    exyz_files_conf_sample/C=CC=O_7conf.xyz / Bmin:  1.70 / Bmax:  3.27 / L:  5.03
#       R/Å     %V_Bur     %S_Bur
#      3.50      25.84       0.00
# 3
#    exyz_files_conf_sample/C=CC=O_8conf.xyz / Bmin:  1.70 / Bmax:  4.43 / L:  4.21
#       R/Å     %V_Bur     %S_Bur
#      3.50      27.17       0.00
# 3
#    exyz_files_conf_sample/C=CC=O_9conf.xyz / Bmin:  1.70 / Bmax:  4.43 / L:  4.21
#       R/Å     %V_Bur     %S_Bur
#      3.50      27.17       0.00

# %%
#electrophiles_to_delete = ['ClC1CCCO1','Cc4ccc(S(=O)(=O)N3CC(/C=C/c1ccccc1)c2ccccc23)cc4']

results_csv_file = 'boltz_max_sterimol_results.csv'
sterimol_df = pd.read_csv(results_csv_file)
sterimol_df["input electrophile SMILES"]=  sterimol_df["smiles"]
# Load additional information from the second CSV file
nresults_csv_file = 'n_boltz_max_sterimol_results.csv'
nsterimol_df = pd.read_csv(nresults_csv_file)
nsterimol_df["nucleophile SMILES"]=  nsterimol_df["smiles"]

import numpy as np

additional_info_csv_file = 'sterimol/merged.csv'
additional_info_df = pd.read_csv(additional_info_csv_file)
print(len(np.unique(additional_info_df["nucleophile SMILES"])))

# Merge DataFrames based on the 'SMILES' column
merged_df = pd.merge( additional_info_df, sterimol_df, on='input electrophile SMILES', how='left')
merged_df = pd.merge( merged_df, nsterimol_df, on='nucleophile SMILES', how='left',suffixes=('_e', '_n'))
#merged_df = merged_df[~merged_df['input electrophile SMILES'].isin(electrophiles_to_delete)]
# Save the merged DataFrame to a new CSV file
merged_csv_file = 'merged_max.csv'
merged_df.to_csv(merged_csv_file, index=False)

print(f"Merged results saved to {merged_csv_file}")
# Out:
# 49
# Merged results saved to merged_max.csv

# %% [markdown]
# # Default conformer Method

# %%
unique_df = df1.drop_duplicates(subset='input electrophile SMILES')

# Find Sterimol parameters for each unique SMILES
results = []
for index, row in unique_df.iterrows():
    properties = []
    c_o_info = find_c_o_atom_ids(row['input electrophile SMILES'])
    if c_o_info:
        smiles = c_o_info['smiles']
        oxygen_atom_id = c_o_info['oxygen_atom_ids']
        carbon_atom_id = c_o_info['carbon_atom_ids']

        # Create .xyz file
        output_folder = 'exyz_files_conf_sample'
        os.makedirs(output_folder, exist_ok=True)
        conf = smiles_to_xyz(smiles, output_folder,'basic')
        for i in range(len(oxygen_atom_id)):
            print(oxygen_atom_id[i])
                #L, Bmin,Bmax,bur_shell,bur_vol, max_distance, tot_V, disp,max_axis,A2,min_axis
            conformer_properties  = run_dbstep(conf, oxygen_atom_id[i], carbon_atom_id[i])
            

       
        results.append({'smiles': smiles, 'L': conformer_properties[0], 'Bmin': conformer_properties[1], 
        'Bmax': conformer_properties[2], 'bur_shell': conformer_properties[3], 'bur_vol': conformer_properties[4], 
        'max_distance': conformer_properties[5], 'tot_V': conformer_properties[6], 'disp': conformer_properties[7],
         'max_axis': conformer_properties[8], 'A2': conformer_properties[9], 'min_axis': conformer_properties[10]})


# Display Sterimol results
results_df = pd.DataFrame(results)

# Save the results to a CSV file
results_csv_file = 'basic_sterimol_results.csv'
results_df.to_csv(results_csv_file, index=False)
# Out:
# 0
#    exyz_files_conf_sample/O=Cc2ccc1ccccc1c2.xyz / Bmin:  1.70 / Bmax:  8.20 / L:  6.13
#       R/Å     %V_Bur     %S_Bur
#      3.50      26
/ L:  5.70
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.37       0.00
# 10
#    exyz_files_conf_sample/CCCC_C=C_1CCCC1=O.xyz / Bmin:  2.41 / Bmax:  8.39 / L:  5.85
#       R/Å     %V_Bur     %S_Bur
#      3.50      32.84       0.00
# 8
#    exyz_files_conf_sample/C_C(C)=C\1CCCC1=O.xyz / Bmin:  2.35 / Bmax:  5.62 / L:  5.38
#       R/Å     %V_Bur     %S_Bur
#      3.50      35.22       0.00
# 10
#    exyz_files_conf_sample/C_C=C_1CCCC(C)(C)C1=O.xyz / Bmin:  2.69 / Bmax:  5.60 / L:  6.06
#       R/Å     %V_Bur     %S_Bur
#      3.50      31.18       0.00
# 9
#    exyz_files_conf_sample/C=C1CCCC(C)(C)C1=O.xyz / Bmin:  2.61 / Bmax:  4.47 / L:  6.14
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.48       0.00
# 3
#    exyz_files_conf_sample/C=C1C(=O)CCCC1(C)C.xyz / Bmin:  2.67 / Bmax:  4.46 / L:  6.34
#       R/Å     %V_Bur     %S_Bur
#      3.50      42.25       0.00
# 8
#    exyz_files_conf_sample/C=C1CCC(C)=CC1=O.xyz / Bmin:  2.20 / Bmax:  4.40 / L:  6.20
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.30       0.00
# 8
#    exyz_files_conf_sample/C=C1CCC=C(C)C1=O.xyz / Bmin:  2.13 / Bmax:  4.47 / L:  6.06
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.02       0.00
# 9
#    exyz_files_conf_sample/C=C1CC(C)(C)C=CC1=O.xyz / Bmin:  2.69 / Bmax:  4.35 / L:  7.31
#       R/Å     %V_Bur     %S_Bur
#      3.50      36.75       0.00
# 11
#    exyz_files_conf_sample/C=C2CCc1ccccc1C2=O.xyz / Bmin:  2.12 / Bmax:  5.69 / L:  6.29
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.01       0.00
# 3
#    exyz_files_conf_sample/COC(=O)_C=C_c1cccc(Br)c1.xyz / Bmin:  1.75 / Bmax:  8.30 / L:  8.60
#       R/Å     %V_Bur     %S_Bur
#      3.50      27.67       0.00
# 3
#    exyz_files_conf_sample/COC(=O)_C=C_c1ccccc1Br.xyz / Bmin:  1.86 / Bmax:  7.02 / L:  8.39
#       R/Å     %V_Bur     %S_Bur
#      3.50      27.15       0.00
# 3
#    exyz_files_conf_sample/COC(=O)_C=C_c1ccc(C(F)(F)F)cc1.xyz / Bmin:  1.94 / Bmax:  8.93 / L:  8.50
#       R/Å     %V_Bur     %S_Bur
#      3.50      27.33       0.00
# 3
#    exyz_files_conf_sample/COC(=O)_C=C_c1cccs1.xyz / Bmin:  1.74 / Bmax:  8.13 / L:  5.97
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.44       0.00
# 3
#    exyz_files_conf_sample/COC(=O)_C=C_CC(C)C.xyz / Bmin:  2.06 / Bmax:  7.85 / L:  4.84
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.49       0.00
# 6
#    exyz_files_conf_sample/CCC_C=C_C(=O)OC.xyz / Bmin:  1.90 / Bmax:  4.58 / L:  8.00
#       R/Å     %V_Bur     %S_Bur
#      3.50      32.07       0.00
# 5
#    exyz_files_conf_sample/CC_C=C_C(=O)OC.xyz / Bmin:  1.82 / Bmax:  5.90 / L:  5.82
#       R/Å     %V_Bur     %S_Bur
#      3.50      31.31       0.00
# 3
#    exyz_files_conf_sample/COC(=O)_C=C_CBr.xyz / Bmin:  1.84 / Bmax:  5.55 / L:  5.94
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.85       0.00
# 4
#    exyz_files_conf_sample/C_C=C_C(=O)OC.xyz / Bmin:  1.81 / Bmax:  4.60 / L:  6.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.68       0.00
# 3
#    exyz_files_conf_sample/C=C(C=O)CC.xyz / Bmin:  1.70 / Bmax:  4.42 / L:  6.19
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.78       0.00
# 3
#    exyz_files_conf_sample/C=C(C=O)Cc1ccccc1.xyz / Bmin:  1.70 / Bmax:  7.05 / L:  7.05
#       R/Å     %V_Bur     %S_Bur
#      3.50      40.92       0.00
# 4
#    exyz_files_conf_sample/C_C=C_C=O.xyz / Bmin:  1.70 / Bmax:  4.60 / L:  5.90
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.55       0.00
# 6
#    exyz_files_conf_sample/CC_C=C(C)_C=O.xyz / Bmin:  1.70 / Bmax:  4.53 / L:  6.92
#       R/Å     %V_Bur     %S_Bur
#      3.50      30.29       0.00
# 0
#    exyz_files_conf_sample/O=CC1=CCCCC1.xyz / Bmin:  1.70 / Bmax:  5.58 / L:  6.13
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.22       0.00
# 4
#    exyz_files_conf_sample/C=C(C)C=O.xyz / Bmin:  1.70 / Bmax:  4.38 / L:  5.21
#       R/Å     %V_Bur     %S_Bur
#      3.50      33.18       0.00
# 12
#    exyz_files_conf_sample/C=CCCCCCCCC(=C)C=O.xyz / Bmin:  1.70 / Bmax:  8.43 / L:  7.09
#       R/Å     %V_Bur     %S_Bur
#      3.50      27.27       0.00
# 3
#    exyz_files_conf_sample/C=C(C=O)CCCCO[Si](C)(C)C(C)(C)C.xyz / Bmin:  1.86 / Bmax:  8.68 / L: 11.32
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.34       0.00
# 3
#    exyz_files_conf_sample/C=C(C=O)Cc1ccccc1F.xyz / Bmin:  1.70 / Bmax:  7.18 / L:  5.16
#       R/Å     %V_Bur     %S_Bur
#      3.50      33.98       0.00
# 5
#    exyz_files_conf_sample/CC_C=C_C=O.xyz / Bmin:  1.70 / Bmax:  5.66 / L:  5.94
#       R/Å     %V_Bur     %S_Bur
#      3.50      31.49       0.00
# 6
#    exyz_files_conf_sample/CCC_C=C_C=O.xyz / Bmin:  1.70 / Bmax:  6.14 / L:  7.81
#       R/Å     %V_Bur     %S_Bur
#      3.50      28.69       0.00
# 10
#    exyz_files_conf_sample/CCCCCCC_C=C_C=O.xyz / Bmin:  1.70 / Bmax: 10.97 / L:  7.76
#       R/Å     %V_Bur     %S_Bur
#      3.50      29.26       0.00
# 7
#    exyz_files_conf_sample/CC(C)C_C=C_C=O.xyz / Bmin:  1.70 / Bmax:  6.87 / L:  6.46
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.86       0.00
# 8
#    exyz_files_conf_sample/CCOC(=O)_C=C_C=O.xyz / Bmin:  1.70 / Bmax:  7.84 / L:  6.34
#       R/Å     %V_Bur     %S_Bur
#      3.50      31.53       0.00
# 9
#    exyz_files_conf_sample/COc1ccc(_C=C_C=O)cc1.xyz / Bmin:  1.70 / Bmax:  8.12 / L:  9.43
#       R/Å     %V_Bur     %S_Bur
#      3.50      28.61       0.00
# 10
#    exyz_files_conf_sample/C=Cc1cccc(_C=C_C=O)c1.xyz / Bmin:  1.70 / Bmax:  8.62 / L:  8.49
#       R/Å     %V_Bur     %S_Bur
#      3.50      29.13       0.00
# 0
#    exyz_files_conf_sample/O=C_C=C_c1ccc(Br)cc1.xyz / Bmin:  1.70 / Bmax:  7.93 / L:  8.98
#       R/Å     %V_Bur     %S_Bur
#      3.50      22.60       0.00
# 0
#    exyz_files_conf_sample/O=C_C=C_c1ccc(Cl)cc1.xyz / Bmin:  1.70 / Bmax:  9.62 / L:  6.10
#       R/Å     %V_Bur     %S_Bur
#      3.50      25.89       0.00
# 0
#    exyz_files_conf_sample/O=C_C=C_c1ccco1.xyz / Bmin:  1.70 / Bmax:  6.82 / L:  7.70
#       R/Å     %V_Bur     %S_Bur
#      3.50      22.77       0.00
# 5
#    exyz_files_conf_sample/C_C=C(C)_C=O.xyz / Bmin:  1.70 / Bmax:  5.49 / L:  5.19
#       R/Å     %V_Bur     %S_Bur
#      3.50      30.83       0.00
# 0
#    exyz_files_conf_sample/O=CC1=CCCC1.xyz / Bmin:  1.70 / Bmax:  5.62 / L:  5.60
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.34       0.00
# 3
#    exyz_files_conf_sample/C=CC=O.xyz / Bmin:  1.70 / Bmax:  4.42 / L:  4.16
#       R/Å     %V_Bur     %S_Bur
#      3.50      27.31       0.00

# %%
unique_df = df1.drop_duplicates(subset='nucleophile SMILES')

# Find Sterimol parameters for each unique SMILES
results = []
for index, row in unique_df.iterrows():
    properties = []
    terminal_double_bonded_carbons = find_terminal_double_bonded_carbons(row['nucleophile SMILES'])
    if terminal_double_bonded_carbons:
        smiles = terminal_double_bonded_carbons['smiles']
        terminal_atom_ids = terminal_double_bonded_carbons['terminal_atoms']
        non_terminal_atoms = terminal_double_bonded_carbons['non_terminal_atoms']
        # Create .xyz file
        output_folder = 'nxyz_files'
        os.makedirs(output_folder, exist_ok=True)
        #output_file_path = os.path.join(output_folder, f'{smiles.replace("/", "_")}.xyz')
        conf = smiles_to_xyz(smiles, output_folder,'basic')
        
            
        conformer_properties = []
        for i in range(len(terminal_atom_ids)):
            print(terminal_atom_ids[i])
                #L, Bmin,Bmax,bur_shell,bur_vol, max_distance, tot_V, disp,max_axis,A2,min_axis
            props  = run_dbstep(conf, terminal_atom_ids[i], non_terminal_atoms[i])
            if props is not None:
                conformer_properties.append(props)

        average_properties_array = np.array(conformer_properties)

        max_L_index = np.argmax(average_properties_array[:, 0])

        
        filtered_properties =  conformer_properties[max_L_index]#[prop for prop in properties if prop[0] == max_L]
        print(filtered_properties )
        results.append({'smiles': smiles, 'L': filtered_properties[0], 'Bmin': filtered_properties[1], 
        'Bmax': filtered_properties[2], 'bur_shell': filtered_properties[3], 'bur_vol': filtered_properties[4], 
        'max_distance': filtered_properties[5], 'tot_V': filtered_properties[6], 'disp': filtered_properties[7],
         'max_axis': filtered_properties[8], 'A2': filtered_properties[9], 'min_axis': filtered_properties[10]})

# Display Sterimol results
results_df = pd.DataFrame(results)

# Save the results to a CSV file
results_csv_file = 'n_basic_sterimol_results.csv'
results_df.to_csv(results_csv_file, index=False)
# Out:
# 0
#    nxyz_files/C=CC[Si](C)(C)C.xyz / Bmin:  1.70 / Bmax:  5.57 / L:  6.26
#       R/Å     %V_Bur     %S_Bur
#      3.50      29.83       0.00
# (6.25947703, 1.7, 5.571337446184442, 0.0, 29.833899858101905, 7.092840855255554, 137.19131243064325, 3.4517850263598393, 6.970084598185735, 0.6909295817944745, 0.5863793607197972)
# 0
#    nxyz_files/C=C(OC)O[Si](C)(C)C(C)(C)C.xyz / Bmin:  2.50 / Bmax:  7.19 / L:  5.94
#       R/Å     %V_Bur     %S_Bur
#      3.50      45.29       0.00
# (5.94236943, 2.495612694542582, 7.186616615806121, 0.0, 45.289651743926164, 9.26463361844307, 232.26908545425442, 4.469333799228263, 9.038164040413047, 0.6136879271509972, 0.5126290011704386)
# 0
#    nxyz_files/C=C(OCc1ccccc1)O[Si](C)(C)C(C)(C)C.xyz / Bmin:  2.30 / Bmax:  7.45 / L:  7.42
#       R/Å     %V_Bur     %S_Bur
#      3.50      41.12       0.00
# (7.41641828, 2.2963535679821288, 7.4523809135448476, 0.0, 41.121762112574466, 11.1379123121278, 350.73023850964876, 7.547148473583437, 10.839504158623708, 0.5723661737683964, 0.4811394884165403)
# 0
#    nxyz_files/C=C(OC1CCCCC1)O[Si](C)(C)C(C)(C)C.xyz / Bmin:  3.23 / Bmax:  7.03 / L:  6.50
#       R/Å     %V_Bur     %S_Bur
#      3.50      43.40       0.00
# (6.49633339, 3.225638673436859, 7.0348103314943735, 0.0, 43.39811287124301, 11.372645538475407, 309.56526247503183, 7.262117212398534, 11.2327434183382, 0.5301355826176628, 0.41200999308516606)
# 0
#    nxyz_files/C=C(O[Si](C)(C)C(C)(C)C)c1ccccc1.xyz / Bmin:  1.79 / Bmax:  7.28 / L:  6.34
#       R/Å     %V_Bur     %S_Bur
#      3.50      42.57       0.00
# (6.33827623, 1.7877825395262579, 7.283222265709329, 0.0, 42.571473131171345, 10.806276624636016, 298.6482156290667, 6.718230535554444, 10.750836175059902, 0.5199285938547299, 0.4622633793755697)
# 0
#    nxyz_files/C=C(_C=C_c1ccccc1)O[Si](C)(C)C(C)(C)C.xyz / Bmin:  2.37 / Bmax:  7.25 / L:  8.43
#       R/Å     %V_Bur     %S_Bur
#      3.50
#       R/Å     %V_Bur     %S_Bur
#      3.50      30.28       0.00
# 3
#    nxyz_files/C=CC(=C)CC_C=C(C)\C.xyz / Bmin:  1.85 / Bmax:  7.27 / L:  5.04
#       R/Å     %V_Bur     %S_Bur
#      3.50      30.28       0.00
# (5.22366332, 1.7, 8.401329786889887, 0.0, 30.284136797838855, 8.720999466694252, 157.1634984051075, 3.6327314382762954, 8.352627832110695, 0.5526255898963842, 0.4880353753091913)
# 0
#    nxyz_files/C=C(C)_C=C(C)_C.xyz / Bmin:  2.08 / Bmax:  4.73 / L:  6.44
#       R/Å     %V_Bur     %S_Bur
#      3.50      32.02       0.00
# (6.43629914, 2.0796285717574703, 4.729796493531717, 0.0, 32.02356989331163, 6.64796442316491, 54.91502590590357, 3.117287374364424, 6.629654865532209, 0.5981588912131162, 0.31506624012723344)
# 0
#    nxyz_files/C=C_C=C_C.xyz / Bmin:  1.70 / Bmax:  4.62 / L:  6.00
#       R/Å     %V_Bur     %S_Bur
#      3.50      26.20       0.00
# (5.9979152, 1.7, 4.62381980390138, 0.0, 26.201836880909095, 6.539018046528695, 31.454418307290467, 2.8638974697253277, 6.507680029473903, 0.4478867359472691, 0.25482080478131663)
# 0
#    nxyz_files/C=C_C=C_CCCCCC.xyz / Bmin:  1.70 / Bmax:  8.42 / L:  8.54
#       R/Å     %V_Bur     %S_Bur
#      3.50      25.99       0.00
# (8.54273222, 1.7, 8.416845584089904, 0.0, 25.993976197206436, 11.438638743809957, 136.83526317095794, 3.244552896529659, 11.347424357145993, 0.3343549803008554, 0.28009047890691796)
# 0
#    nxyz_files/C=C_C=C_C1CCCCC1.xyz / Bmin:  1.70 / Bmax:  5.58 / L:  9.00
#       R/Å     %V_Bur     %S_Bur
#      3.50      25.98       0.00
# (8.99649217, 1.7, 5.582931755026592, 0.0, 25.984219621866934, 9.578413264955877, 134.50284103626697, 8.66556170859517, 9.569411572170909, 0.45620463927736854, 0.3364465346884435)
# 0
#    nxyz_files/C=C(C)_C=C_C.xyz / Bmin:  1.79 / Bmax:  4.46 / L:  6.10
#       R/Å     %V_Bur     %S_Bur
#      3.50      31.75       0.00
# (6.10291954, 1.7946998200000002, 4.462669646677867, 0.0, 31.754279452085317, 6.534600025561801, 44.3217011760343, 3.099741137382955, 6.400425002789661, 0.6168678445469158, 0.27402983531210995)
# 0
#    nxyz_files/C=C(C)C1=CCCCC1.xyz / Bmin:  2.13 / Bmax:  5.68 / L:  6.37
#       R/Å     %V_Bur     %S_Bur
#      3.50      35.35       0.00
# (6.3739138099999995, 2.1277759474086104, 5.675883264872809, 0.0, 35.353157677059265, 7.180426627224518, 87.76894001781899, 5.889666571653663, 7.010743157310719, 0.6143928655075844, 0.41457443659914195)
# 0
#    nxyz_files/C=C(_C=C_C(C)(C)C)C(C)(C)C.xyz / Bmin:  3.03 / Bmax:  5.93 / L:  7.03
#       R/Å     %V_Bur     %S_Bur
#      3.50      39.75       0.00
# (7.02565971, 3.031801775517553, 5.929626477442964, 0.0, 39.748499225069594, 8.4166746328816, 169.67685641041598, 6.645180791101853, 8.07030839815802, 0.6445363063881455, 0.5008467155209688)
# 0
#    nxyz_files/C=C(C)_C=C_CCOCc1ccccc1.xyz / Bmin:  1.91 / Bmax:  8.85 / L:  7.42
#       R/Å     %V_Bur     %S_Bur
#      3.50      31.50       0.00
# (7.418055519999999, 1.9059489049625427, 8.850736933018586, 0.0, 31.498628078816022, 9.51591234475546, 246.08416228678442, 9.0438735791822, 9.177252683215894, 0.6235850816641493, 0.5105636343923797)
# 0
#    nxyz_files/C1=CCC=C1.xyz / Bmin:  1.70 / Bmax:  4.38 / L:  3.53
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.76       0.00
# 1
#    nxyz_files/C1=CCC=C1.xyz / Bmin:  1.70 / Bmax:  4.38 / L:  3.94
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.76       0.00
# 3
#    nxyz_files/C1=CCC=C1.xyz / Bmin:  1.70 / Bmax:  4.37 / L:  3.97
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.76       0.00
# 4
#    nxyz_files/C1=CCC=C1.xyz / Bmin:  1.70 / Bmax:  4.37 / L:  3.52
#       R/Å     %V_Bur     %S_Bur
#      3.50      34.76       0.00
# (3.96839091, 1.7000000015643446, 4.366653160000026, 0.0, 34.75788394915953, 4.444615370597324, 30.722925345530495, 3.204208093422417, 4.444082005566052, 0.8496819598241321, 0.411964672425363)
# 0
#    nxyz_files/C1=CCCC=C1.xyz / Bmin:  1.70 / Bmax:  4.38 / L:  3.93
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.23       0.00
# 1
#    nxyz_files/C1=CCCC=C1.xyz / Bmin:  1.70 / Bmax:  4.38 / L:  4.28
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.23       0.00
# 4
#    nxyz_files/C1=CCCC=C1.xyz / Bmin:  1.70 / Bmax:  4.42 / L:  4.21
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.23       0.00
# 5
#    nxyz_files/C1=CCCC=C1.xyz / Bmin:  1.70 / Bmax:  4.42 / L:  3.91
#       R/Å     %V_Bur     %S_Bur
#      3.50      37.23       0.00
# (4.28097214, 1.7, 4.380941862017349, 0.0, 37.23143246231352, 4.96213159841638, 39.00500886256336, 2.367260579107127, 4.80599312340601, 0.9210729865860312, 0.381484502960343)

# %%
electrophiles_to_delete = ['ClC1CCCO1','Cc4ccc(S(=O)(=O)N3CC(/C=C/c1ccccc1)c2ccccc23)cc4']

results_csv_file = 'basic_sterimol_results.csv'
sterimol_df = pd.read_csv(results_csv_file)
sterimol_df["input electrophile SMILES"]=  sterimol_df["smiles"]
# Load additional information from the second CSV file
nresults_csv_file = 'n_basic_sterimol_results.csv'
nsterimol_df = pd.read_csv(nresults_csv_file)
nsterimol_df["nucleophile SMILES"]=  nsterimol_df["smiles"]


additional_info_csv_file = 'sterimol/merged.csv'
additional_info_df = pd.read_csv(additional_info_csv_file)

# Merge DataFrames based on the 'SMILES' column
merged_df = pd.merge( additional_info_df, sterimol_df, on='input electrophile SMILES', how='left')
merged_df = pd.merge( merged_df, nsterimol_df, on='nucleophile SMILES', how='left',suffixes=('_e', '_n'))
merged_df = merged_df[~merged_df['input electrophile SMILES'].isin(electrophiles_to_delete)]
# Save the merged DataFrame to a new CSV file
merged_csv_file = 'merged_default.csv'
merged_df.to_csv(merged_csv_file, index=False)

print(f"Merged results saved to {merged_csv_file}")
# Out:
# Merged results saved to merged_default.csv
